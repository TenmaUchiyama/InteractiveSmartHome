# %%
import os 
import subprocess

# %%
import json
import pandas as pd
df = pd.read_csv("latin_square.csv")
index = 0
p1 = df.iloc[0]


#研究被験者の取得
participant = f"P{index+1}"
taskSet = p1["Task Set 1"]
condition_num = int(p1["Condition 1_ConditionNum"])




#ArrangeDataを取得する
with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/ArrangeData/PreTaskArrangement{taskSet}.json", "r", encoding="utf-8") as f:
    arrangeData = json.loads(f.read())

with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/VOICE_LOG/{participant}/{condition_num}_{taskSet}.json", "r", encoding="utf-8") as f:
    voice_log = json.loads(f.read())

# %%
with open(f"../LLMServer/ExperimentData/RESULTS/P1/P1_1.json", "r", encoding="utf-8") as f:
    result_data = json.loads(f.read())


result_data[-1]
# Out:
# {'user_prompt': '今見ている天井のライト。 左の列を赤 真ん中の列を黄色。 右の列を青にしてください 合計六個のライトが 転倒するはずです',
#  'filterAgent': {'output_tool_selection': {'filter_type': 'fov',
#    'params': {'isInFov': True, 'order': 'centrality', 'range': 0.0},
#    'reasoning': '『左の列』『真ん中の列』『右の列』という視覚的レイアウトの表現があり、身体参照ではないため、fovを選んだ。'},
#   'devices': [{'id': '2dc8ca39-d023-42a5-874d-76fb312b5f00',
#     'name': 'Ceiling Light 5',
#     'position': {'x': -0.4464956, 'y': 2.23415518, 'z': 4.37419748},
#     'distance_from_user': 4.931978,
#     'eye_centrality_score': 2.91055417},
#    {'id': '58126407-cde0-4d62-a13d-1a24bf8ea5f3',
#     'name': 'Ceiling Light 6',
#     'position': {'x': 0.3735784, 'y': 2.23415518, 'z': 2.55757856},
#     'distance_from_user': 3.416463,
#     'eye_centrality_score': 15.4298306},
#    {'id': '2125de35-62c2-40db-8bee-f0580a92ee8b',
#     'name': 'Ceiling Light 1',
#     'position': {'x': 1.34820163, 'y': 2.222155, 'z': 5.21053457},
#     'distance_from_user': 5.822825,
#     'eye_centrality_score': 18.6302319},
#    {'id': 'c689031b-92fe-41bc-a9bc-5f579631c813',
#     'name': 'Ceiling Light 9',
#     'position': {'x': -2.27654386, 'y': 2.23415518, 'z': 3.52138638},
#     'distance_from_user': 4.75123835,
#     'eye_centrality_score': 24.9980183},
#    {'id': '541d973c-4101-4118-ae52-f8f192b69655',
#     'name': 'Ceiling Light 10',
#     'position': {'x': -1.43682718, 'y': 2.23415518, 'z': 1.71943712},
#     'distance_from_user': 3.16423535,
#     'eye_centrality_score': 32.1271248},
#    {'id': '781e6091-cec9-4c26-9f3e-4d48d6d7570a',
#     'name': 'Ceiling Light 2',
#     'position': {'x': 2.18918538, 'y': 2.222155, 'z': 3.40586615},
#     'distance_from_user': 4.618488,
#     'eye_centrality_score': 33.80741}],
#   'metrics': {'model_name': 'gpt-4o-2024-08-06',
#    'tokens': {'prompt_tokens': 1415,
#     'completion_tokens': 97,
#     'total_tokens': 1512},
#    'cost_usd': 0.004508,
#    'agent_time_elapsed': 2.5606002807617188,
#    'system_time_elapsed': 2.897580146789551}},
#  'spatialAgent': {'output_data': {'devices': [{'id': 'c689031b-92fe-41bc-a9bc-5f579631c813',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 255, 'g': 0, 'b': 0}},
#     {'id': '541d973c-4101-4118-ae52-f8f192b69655',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 255, 'g': 0, 'b': 0}},
#     {'id': '2dc8ca39-d023-42a5-874d-76fb312b5f00',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 255, 'g': 255, 'b': 0}},
#     {'id': '58126407-cde0-4d62-a13d-1a24bf8ea5f3',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 255, 'g': 255, 'b': 0}},
#     {'id': '2125de35-62c2-40db-8bee-f0580a92ee8b',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 0, 'g': 0, 'b': 255}},
#     {'id': '781e6091-cec9-4c26-9f3e-4d48d6d7570a',
#      'state': True,
#      'intensity': 100,
#      'color': {'r': 0, 'g': 0, 'b': 255}}],
#    'response': '左の列を赤色、真ん中の列を黄色、右の列を青色にしました。',
#    'reasoning': 'x座標に基づいてデバイスを左、中央、右の列に分けました。左の列には最もx座標が小さいデバイス、中央の列には中間のx座標を持つデバイス、右の列にはx座標が最も大きいデバイスが配置されています。色は指示通りに割り当てました。'},
#   'metrics': {'model_name': 'gpt-4o-2024-08-06',
#    'tokens': {'prompt_tokens': 2802,
#     'completion_tokens': 553,
#     'total_tokens': 3355},
#    'cost_usd': 0.012535,
#    'agent_time_elapsed': 5.172547340393066,
#    'system_time_elapsed': 5.504989862442017}},
#  'selected_devices': [{'id': 'c689031b-92fe-41bc-a9bc-5f579631c813',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 255, 'g': 0, 'b': 0}},
#   {'id': '541d973c-4101-4118-ae52-f8f192b69655',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 255, 'g': 0, 'b': 0}},
#   {'id': '2dc8ca39-d023-42a5-874d-76fb312b5f00',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 255, 'g': 255, 'b': 0}},
#   {'id': '58126407-cde0-4d62-a13d-1a24bf8ea5f3',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 255, 'g': 255, 'b': 0}},
#   {'id': '2125de35-62c2-40db-8bee-f0580a92ee8b',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 0, 'g': 0, 'b': 255}},
#   {'id': '781e6091-cec9-4c26-9f3e-4d48d6d7570a',
#    'state': True,
#    'intensity': 100,
#    'color': {'r': 0, 'g': 0, 'b': 255}}],
#  'system_metrics': None,
#  'task_id': 'fd995852-c28d-49e9-97b5-9774af3241c3',
#  'attempt_id': '2dd5179d-a406-4a53-a174-f8ab45102d56'}

# %%
outputData[0]["task_id"]="3a642a22-d8be-466d-ae3d-8ee4ae7e730f"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 outputData[0]["task_id"]="3a642a22-d8be-466d-ae3d-8ee4ae7e730f"
#
# NameError: name 'outputData' is not defined

# %%
def evaluate_all_predictions(output_data_list, arrange_data_list):
    results = []

    # arrange_data を dict に変換して素早くアクセス
    arrange_map = {
        entry["device_arrange_id"]: [dev["deviceId"] for dev in entry["devices"]]
        for entry in arrange_data_list
    }

    for output in output_data_list:
        task_id = output.get("task_id")
        predicted_ids = [d["id"] for d in output.get("selected_devices", [])]
        ground_truth_ids = arrange_map.get(task_id)

        if ground_truth_ids is None:
            print(f"[⚠️ Warning] Ground truth not found for task_id: {task_id}")
            continue

        gt_set = set(ground_truth_ids)
        pred_set = set(predicted_ids)

        true_positives = gt_set & pred_set
        false_positives = pred_set - gt_set
        false_negatives = gt_set - pred_set

        precision = len(true_positives) / len(pred_set) if pred_set else 0
        recall = len(true_positives) / len(gt_set) if gt_set else 0

        results.append({
            "task_id": task_id,
            "ground_truth": ground_truth_ids,
            "predicted": predicted_ids,
            "true_positives": list(true_positives),
            "false_positives": list(false_positives),
            "false_negatives": list(false_negatives),
            "precision": precision,
            "recall": recall
        })

    return results

# %%
results = evaluate_all_predictions(outputData, arrangeData)
import pprint
pprint.pprint(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 results = evaluate_all_predictions(outputData, arrangeData)
#       2 import pprint
#       3 pprint.pprint(results)
#
# NameError: name 'outputData' is not defined

# %%
import pandas as pd
import re

# CSVの読み込み
condition = pd.read_csv("latin_square_design.csv")

# 変換用マッピング
replace_map = {
    "FD+SR": "空間参照だけ",
    "Pointing": "ポインティングだけ",
    "Pointing+SR": "Pointing+空間参照",
    "Label": "ラベル"
}

# Condition列だけを対象に処理
for col in condition.columns:
    if "Condition" in col:
        # ()の中の数字を取り出し、新しい列に保存
        condition[col + "_ConditionNum"] = condition[col].str.extract(r"\((\d+)\)").astype(float)

        # ()を除いた本体部分を変換
        condition[col] = condition[col].str.replace(r"\(\d+\)", "", regex=True).str.strip()
        condition[col] = condition[col].replace(replace_map)

# 結果を表示
condition.to_csv("./latin_square_design.csv", index=False)
