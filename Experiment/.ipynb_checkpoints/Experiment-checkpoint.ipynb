# %%
import os 
import subprocess

# %%
import json
import pandas as pd
df = pd.read_csv("latin_square_design.csv")
index = 0
p1 = df.iloc[0]


#研究被験者の取得
participant = f"P{index+7}"
taskSet = p1["Task Set 1"]
condition_num = int(p1["Condition 1_ConditionNum"])




#ArrangeDataを取得する
with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/ArrangeData/PreTaskArrangement{taskSet}.json", "r", encoding="utf-8") as f:
    arrangeData = json.loads(f.read())

with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/VOICE_LOG/{participant}/{condition_num}_{taskSet}.json", "r", encoding="utf-8") as f:
    voice_log = json.loads(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 20
#      17 with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/ArrangeData/PreTaskArrangement{taskSet}.json", "r", encoding="utf-8") as f:
#      18     arrangeData = json.loads(f.read())
# ---> 20 with open(f"../InteractiveSmartHome/Assets/EXPERIMENT/VOICE_LOG/{participant}/{condition_num}_{taskSet}.json", "r", encoding="utf-8") as f:
#      21     voice_log = json.loads(f.read())
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../InteractiveSmartHome/Assets/EXPERIMENT/VOICE_LOG/P7/1_C.json'

# %%
with open(f"../LLMServer/ExperimentData/RESULTS/P1.json", "r", encoding="utf-8") as f:
    result_data = json.loads(f.read())


result_data[-1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 with open(f"../LLMServer/ExperimentData/RESULTS/P1.json", "r", encoding="utf-8") as f:
#       2     result_data = json.loads(f.read())
#       5 result_data[-1]
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../LLMServer/ExperimentData/RESULTS/P1.json'

# %%
voice_log
# Out:
# [{'taskId': '7612d934-759d-4a55-9a58-ef65940b7162',
#   'taskAttemptCount': 0,
#   'finalId': '516c5e1e-68d5-443b-ba5c-e8c3c3d9c750',
#   'taskAttempts': [{'attemptId': '516c5e1e-68d5-443b-ba5c-e8c3c3d9c750',
#     'taskElapsedTime': '28.12045',
#     'userCommand': '',
#     'outputDevices': ['2125de35-62c2-40db-8bee-f0580a92ee8b',
#      '7b870bf8-74c9-4aac-9e1e-b0e209a6472f',
#      '4cf87da5-fadb-4383-b959-8562091cb367',
#      'dcc0f42b-a4c0-4cdb-8d11-cc7e3e30ed71',
#      '84133dee-2ea3-4fcb-9036-56f264096fac']}]},
#  {'taskId': 'b0e9f035-c92f-4dc6-bd0a-a10b2941f902',
#   'taskAttemptCount': 0,
#   'finalId': '98566e1f-93be-4faa-a811-f591a4c09373',
#   'taskAttempts': [{'attemptId': '98566e1f-93be-4faa-a811-f591a4c09373',
#     'taskElapsedTime': '20.92029',
#     'userCommand': '',
#     'outputDevices': ['4cf87da5-fadb-4383-b959-8562091cb367']}]},
#  {'taskId': 'ff4748e2-cd97-45bb-bf2c-e5c9c33f78ac',
#   'taskAttemptCount': 1,
#   'finalId': 'a405c211-98cb-4a9a-8af0-c772351b90d0',
#   'taskAttempts': [{'attemptId': 'a405c211-98cb-4a9a-8af0-c772351b90d0',
#     'taskElapsedTime': '26.26041',
#     'userCommand': '',
#     'outputDevices': ['b9091f32-63d4-49f9-8677-f2a8c167cc62']}]},
#  {'taskId': '04f5e376-2845-485a-8cb1-c38e3858ff8a',
#   'taskAttemptCount': 0,
#   'finalId': '14352059-5bfc-48fa-9c65-2f50e129f3f5',
#   'taskAttempts': [{'attemptId': '9de81cc7-d196-4cda-a67b-386b0de20550',
#     'taskElapsedTime': '17.30021',
#     'userCommand': '',
#     'outputDevices': []},
#    {'attemptId': '14352059-5bfc-48fa-9c65-2f50e129f3f5',
#     'taskElapsedTime': '0',
#     'userCommand': '',
#     'outputDevices': ['6f1c35e2-1ca1-4f43-93cf-755d9479025b',
#      '6ac4ec9f-0326-4619-b79a-ecbbe5459d23',
#      'e9a21485-0eb4-40ad-a985-cef8bc98d190',
#      '74a6f0f8-be5d-479e-9e08-91d6bd599916']}]},
#  {'taskId': '1ff814e6-7f85-4e81-ad9f-9aababb20e6d',
#   'taskAttemptCount': 6,
#   'finalId': 'f249f0a0-a011-44af-acf3-5bac0f96b87c',
#   'taskAttempts': [{'attemptId': 'c38d5025-9b2c-4b1e-ae6b-05b1cecb8e46',
#     'taskElapsedTime': '18.76024',
#     'userCommand': '',
#     'outputDevices': ['7b870bf8-74c9-4aac-9e1e-b0e209a6472f',
#      '6dc0f2a7-49f5-4feb-acb5-c243e65c6241',
#      '6093cfc6-9ec0-4c71-948e-6e82e920bdb6',
#      '84133dee-2ea3-4fcb-9036-56f264096fac']},
#    {'attemptId': 'e15febe4-c33a-487e-976d-a6e55b7c4290',
#     'taskElapsedTime': '16.58019',
#     'userCommand': '',
#     'outputDevices': []},
#    {'attemptId': 'deb4b24b-adab-4e4c-a852-50c5db5265bb',
#     'taskElapsedTime': '0',
#     'userCommand': '',
#     'outputDevices': []},
#    {'attemptId': '55e50d94-659b-4ca0-ae2f-105298617313',
#     'taskElapsedTime': '0',
#     'userCommand': '',
#     'outputDevices': ['4cf87da5-fadb-4383-b959-8562091cb367']},
#    {'attemptId': 'a192d9a1-bfa5-475f-9d01-40954aedba17',
#     'taskElapsedTime': '28.16045',
#     'userCommand': '',
#     'outputDevices': ['dcc0f42b-a4c0-4cdb-8d11-cc7e3e30ed71']},
#    {'attemptId': 'f249f0a0-a011-44af-acf3-5bac0f96b87c',
#     'taskElapsedTime': '11.36007',
#     'userCommand': '',
#     'outputDevices': ['dcc0f42b-a4c0-4cdb-8d11-cc7e3e30ed71',
#      'b9091f32-63d4-49f9-8677-f2a8c167cc62']}]},
#  {'taskId': '4e23551b-4fd6-49d6-bc2b-c11836bf2a24',
#   'taskAttemptCount': 0,
#   'finalId': 'a8ddf969-8645-4a86-8643-eeda57fdca2c',
#   'taskAttempts': [{'attemptId': 'a8ddf969-8645-4a86-8643-eeda57fdca2c',
#     'taskElapsedTime': '15.28016',
#     'userCommand': '',
#     'outputDevices': ['6e82a90c-d3bb-4e45-b221-ebe21c524b04',
#      'badaeb49-9e87-4d7b-882e-be2e80f85c84']}]},
#  {'taskId': 'b594ae95-d981-4868-ae48-3f63eb87087a',
#   'taskAttemptCount': 0,
#   'finalId': '751b30c2-e219-4af3-a85d-ce551e0d8bce',
#   'taskAttempts': [{'attemptId': '36dbf3ba-1cce-414e-bce3-65abf497d45e',
#     'taskElapsedTime': '30.86052',
#     'userCommand': '',
#     'outputDevices': ['409f6dff-d2e2-43c8-8ba5-2492b3e2e5d6',
#      'b83f2720-25dd-4c31-81d4-53226d3b2c32']},
#    {'attemptId': '751b30c2-e219-4af3-a85d-ce551e0d8bce',
#     'taskElapsedTime': '0',
#     'userCommand': '',
#     'outputDevices': ['409f6dff-d2e2-43c8-8ba5-2492b3e2e5d6',
#      'b83f2720-25dd-4c31-81d4-53226d3b2c32',
#      'f2505762-f11e-446b-a340-90bbfae0460b',
#      'c1a882b6-ece9-4762-991f-3011f4ef8677']}]},
#  {'taskId': 'e81806f6-a4f2-4336-b77b-3407e101bc18',
#   'taskAttemptCount': 0,
#   'finalId': 'bf63e840-30fe-45df-becb-722a610266e2',
#   'taskAttempts': [{'attemptId': 'bf63e840-30fe-45df-becb-722a610266e2',
#     'taskElapsedTime': '33.78058',
#     'userCommand': '',
#     'outputDevices': ['b83f2720-25dd-4c31-81d4-53226d3b2c32',
#      'f2505762-f11e-446b-a340-90bbfae0460b',
#      'f476b5d2-b938-4bc4-a696-b87b21488598']}]},
#  {'taskId': '3bc363f5-3c91-4c51-8139-93034b21f3a9',
#   'taskAttemptCount': 0,
#   'finalId': 'fa421bdd-18c9-49a7-be47-a2776d25c607',
#   'taskAttempts': [{'attemptId': 'fa421bdd-18c9-49a7-be47-a2776d25c607',
#     'taskElapsedTime': '14.32014',
#     'userCommand': '',
#     'outputDevices': ['b9091f32-63d4-49f9-8677-f2a8c167cc62']}]},
#  {'taskId': 'e0153245-d5d9-449a-87f1-2a35d3239eef',
#   'taskAttemptCount': 0,
#   'finalId': 'a504faf8-ed4d-4cd5-8e31-c97deda45cf1',
#   'taskAttempts': [{'attemptId': 'a504faf8-ed4d-4cd5-8e31-c97deda45cf1',
#     'taskElapsedTime': '27.40044',
#     'userCommand': '',
#     'outputDevices': ['409f6dff-d2e2-43c8-8ba5-2492b3e2e5d6',
#      '80e64f7b-0589-4de7-977a-9d189a66fd1d',
#      '7ad8857c-4547-4f42-bcc0-dc17bd8e6fee',
#      'b83f2720-25dd-4c31-81d4-53226d3b2c32',
#      'f2505762-f11e-446b-a340-90bbfae0460b',
#      'f476b5d2-b938-4bc4-a696-b87b21488598']}]},
#  {'taskId': '3d9e0045-08fb-4a50-b4e5-e4b24c3554c9',
#   'taskAttemptCount': 0,
#   'finalId': '',
#   'taskAttempts': []},
#  {'taskId': 'fd995852-c28d-49e9-97b5-9774af3241c3',
#   'taskAttemptCount': 0,
#   'finalId': '2dd5179d-a406-4a53-a174-f8ab45102d56',
#   'taskAttempts': [{'attemptId': '2dd5179d-a406-4a53-a174-f8ab45102d56',
#     'taskElapsedTime': '45.02084',
#     'userCommand': '',
#     'outputDevices': ['2125de35-62c2-40db-8bee-f0580a92ee8b',
#      '781e6091-cec9-4c26-9f3e-4d48d6d7570a',
#      '2dc8ca39-d023-42a5-874d-76fb312b5f00',
#      '58126407-cde0-4d62-a13d-1a24bf8ea5f3',
#      'c689031b-92fe-41bc-a9bc-5f579631c813',
#      '541d973c-4101-4118-ae52-f8f192b69655']}]}]

# %%
def evaluate_all_predictions(output_data_list, arrange_data_list):
    results = []

    # arrange_data を dict に変換して素早くアクセス
    arrange_map = {
        entry["device_arrange_id"]: [dev["deviceId"] for dev in entry["devices"]]
        for entry in arrange_data_list
    }

    for output in output_data_list:
        task_id = output.get("task_id")
        predicted_ids = [d["id"] for d in output.get("selected_devices", [])]
        ground_truth_ids = arrange_map.get(task_id)

        if ground_truth_ids is None:
            print(f"[⚠️ Warning] Ground truth not found for task_id: {task_id}")
            continue

        gt_set = set(ground_truth_ids)
        pred_set = set(predicted_ids)

        true_positives = gt_set & pred_set
        false_positives = pred_set - gt_set
        false_negatives = gt_set - pred_set

        precision = len(true_positives) / len(pred_set) if pred_set else 0
        recall = len(true_positives) / len(gt_set) if gt_set else 0

        results.append({
            "task_id": task_id,
            "ground_truth": ground_truth_ids,
            "predicted": predicted_ids,
            "true_positives": list(true_positives),
            "false_positives": list(false_positives),
            "false_negatives": list(false_negatives),
            "precision": precision,
            "recall": recall
        })

    return results

# %%
results = evaluate_all_predictions(outputData, arrangeData)
import pprint
pprint.pprint(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = evaluate_all_predictions(outputData, arrangeData)
#       2 import pprint
#       3 pprint.pprint(results)
#
# NameError: name 'evaluate_all_predictions' is not defined

# %%
import pandas as pd
import re

# CSVの読み込み
condition = pd.read_csv("latin_square_design.csv")

# 変換用マッピング
replace_map = {
    "FD+SR": "空間参照だけ",
    "Pointing": "ポインティングだけ",
    "Pointing+SR": "Pointing+空間参照",
    "Label": "ラベル"
}

# Condition列だけを対象に処理
for col in condition.columns:
    if "Condition" in col:
        # ()の中の数字を取り出し、新しい列に保存
        condition[col + "_ConditionNum"] = condition[col].str.extract(r"\((\d+)\)").astype(float)

        # ()を除いた本体部分を変換
        condition[col] = condition[col].str.replace(r"\(\d+\)", "", regex=True).str.strip()
        condition[col] = condition[col].replace(replace_map)

# 結果を表示
condition.to_csv("./latin_square_design.csv", index=False)
