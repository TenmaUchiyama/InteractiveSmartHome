# %%
import os 
import subprocess

# %%
import json

with open("../InteractiveSmartHome/Assets/EXPERIMENT/ArrangeData/PreTaskArrangement.json", "r", encoding="utf-8") as f:
    arrangeData = json.loads(f.read())


with open(r"..\LLMServer\workspace\logs\RESULTS\TEST.json", "r", encoding="utf-8") as f:
    outputData = json.load(f)

# %%
print("=========== OutputData =========")
print(outputData)

print("==========  Arrange Data ========") 
print(arrangeData)
# Out:
# =========== OutputData =========
# [{'user_prompt': '右上の電気を点けて', 'filterAgent': {'output_tool_selection': {'filter_type': 'fov', 'params': {'isInFov': True, 'order': 'right', 'range': 0.0}, 'reasoning': "The instruction '右上' (upper right) refers to a spatial layout from the user's viewpoint, indicating a 'fov' filter with 'right' order."}, 'devices': [{'id': '5267d97b-9929-4288-a957-15fd46185712', 'name': '壁ランプ２', 'position': {'x': 2.52999139, 'y': 0.7764834, 'z': 1.15601325}, 'distance_from_user': 2.88793159}, {'id': '3f613e25-0fa0-4780-9896-adcdf01474c2', 'name': '棚ライト３', 'position': {'x': 2.33054113, 'y': 0.663786948, 'z': 2.918017}, 'distance_from_user': 3.793001}, {'id': '34bf7b7e-946d-4afc-a929-58a4cbebd694', 'name': '天井ライト1', 'position': {'x': 1.71231008, 'y': 1.77185059, 'z': 1.5905087}, 'distance_from_user': 2.93277645}, {'id': '601d6067-28af-42f8-b223-e0da64c17b80', 'name': '棚ライト９', 'position': {'x': 1.64200866, 'y': -0.799537241, 'z': 2.95157146}, 'distance_from_user': 3.470911}, {'id': 'd9cb9ee6-5360-4ac1-9bbe-e2d1b7bfd3da', 'name': '棚ライト６', 'position': {'x': 1.361552, 'y': -0.1086862, 'z': 3.21199751}, 'distance_from_user': 3.49035287}, {'id': '6b667d24-1b1c-4504-b872-436f916476a0', 'name': '棚ライト８', 'position': {'x': 0.605511546, 'y': -0.8174536, 'z': 3.421036}, 'distance_from_user': 3.569084}, {'id': '9c16ad5a-028e-43fd-9747-45177ce1cb9d', 'name': '棚ライト５', 'position': {'x': 0.577348053, 'y': -0.122241542, 'z': 3.56719}, 'distance_from_user': 3.6156764}, {'id': 'abacf8b8-0adc-4c75-9417-f0b5bc5bdbcf', 'name': '棚ライト２', 'position': {'x': 0.116483808, 'y': 0.6432283, 'z': 3.92423463}, 'distance_from_user': 3.978307}, {'id': 'bce898b8-d5d6-45ac-b337-a2820b37c357', 'name': '天井ライト4', 'position': {'x': -0.118409991, 'y': 1.74020576, 'z': 2.41970372}, 'distance_from_user': 2.98283458}, {'id': '80b0cdd4-de6c-4b2e-a70c-ffb663fa4812', 'name': '棚ライト4', 'position': {'x': -0.7806637, 'y': -0.14571543, 'z': 4.18227959}, 'distance_from_user': 4.257009}, {'id': '81406953-308f-4a7d-bc6b-340c969cbc29', 'name': '天井ライト5', 'position': {'x': -0.951771259, 'y': 2.09044075, 'z': 0.593151331}, 'distance_from_user': 2.37226462}, {'id': '6c0bfac2-aa23-47a3-b3ac-db21253cbfae', 'name': '棚ライト７', 'position': {'x': -1.61047912, 'y': -0.8557581, 'z': 4.424733}, 'distance_from_user': 4.78583574}, {'id': '418ab535-e644-4f10-820f-058cf2057eb0', 'name': '棚ライト1', 'position': {'x': -1.702507, 'y': 0.5940738, 'z': 4.744721}, 'distance_from_user': 5.075808}, {'id': '36b0460e-36d2-4f5a-88a5-5174657039f1', 'name': '天井ライト7', 'position': {'x': -1.93091333, 'y': 1.70887578, 'z': 3.24064779}, 'distance_from_user': 4.14131355}, {'id': '1c33a40f-f48c-49f5-8383-d1c006559204', 'name': '天井ライト8', 'position': {'x': -2.7642746, 'y': 2.05911088, 'z': 1.4140954}, 'distance_from_user': 3.7256968}, {'id': '0cbbbed7-ff3c-4932-878d-63a0af564aa8', 'name': 'ランプスタンド', 'position': {'x': -4.40519476, 'y': -1.18590093, 'z': 0.3065083}, 'distance_from_user': 4.572313}], 'metrics': {'model_name': 'gpt-4o-2024-08-06', 'tokens': {'prompt_tokens': 1107, 'completion_tokens': 86, 'total_tokens': 1193}, 'cost_usd': 0.003628, 'agent_time_elapsed': 2.111133337020874, 'system_time_elapsed': 2.362532377243042}}, 'spatialAgent': {'output_data': {'devices': [{'id': '5267d97b-9929-4288-a957-15fd46185712', 'state': True, 'intensity': 100, 'color': {'r': 255, 'g': 255, 'b': 255}}, {'id': '3f613e25-0fa0-4780-9896-adcdf01474c2', 'state': True, 'intensity': 100, 'color': {'r': 255, 'g': 255, 'b': 255}}], 'response': 'Turned on the lights in the upper right area.', 'reasoning': "The command 'upper right' indicates choosing devices with both higher x and y values. The devices with the highest x and y values were selected as they best match the description of being in the 'upper right' from the user's viewpoint."}, 'metrics': {'model_name': 'gpt-4o-2024-08-06', 'tokens': {'prompt_tokens': 2814, 'completion_tokens': 216, 'total_tokens': 3030}, 'cost_usd': 0.009195, 'agent_time_elapsed': 3.760355234146118, 'system_time_elapsed': 8.273782014 ...
# ==========  Arrange Data ========
# [{'device_arrange_id': '3a642a22-d8be-466d-ae3d-8ee4ae7e730f', 'device_arrange_name': '6個の天井のデバイス', 'device_arrange_type': [], 'devices': [{'deviceName': '天井ライト9', 'colorName': 'White', 'deviceId': 'a65c2e1d-fbe8-4bf5-a49b-0ea4ad1db5c3'}, {'deviceName': '天井ライト6', 'colorName': 'White', 'deviceId': 'c364e75e-13c7-4a1f-a48b-c431eff17e45'}, {'deviceName': '天井ライト5', 'colorName': 'White', 'deviceId': '81406953-308f-4a7d-bc6b-340c969cbc29'}, {'deviceName': '天井ライト4', 'colorName': 'White', 'deviceId': 'bce898b8-d5d6-45ac-b337-a2820b37c357'}, {'deviceName': '天井ライト7', 'colorName': 'White', 'deviceId': '36b0460e-36d2-4f5a-88a5-5174657039f1'}, {'deviceName': '天井ライト8', 'colorName': 'White', 'deviceId': '1c33a40f-f48c-49f5-8383-d1c006559204'}]}, {'device_arrange_id': '7067fd6d-160b-4aed-995d-72160cab090e', 'device_arrange_name': '奥の列の右二つ', 'device_arrange_type': [], 'devices': [{'deviceName': '天井ライト7', 'colorName': 'White', 'deviceId': '36b0460e-36d2-4f5a-88a5-5174657039f1'}, {'deviceName': '天井ライト8', 'colorName': 'White', 'deviceId': '1c33a40f-f48c-49f5-8383-d1c006559204'}]}, {'device_arrange_id': '7ab7ff90-5bd1-4f82-858a-dcc110e978db', 'device_arrange_name': '後ろの壁の真ん中の電気', 'device_arrange_type': [], 'devices': [{'deviceName': '壁ランプ１', 'colorName': 'White', 'deviceId': '038f044b-b430-48d7-840c-d8279a6aab6e'}]}, {'device_arrange_id': 'd8bac779-0d43-430b-9011-52868713e7cd', 'device_arrange_name': '目の前の電気', 'device_arrange_type': [], 'devices': [{'deviceName': 'テーブルライト', 'colorName': 'White', 'deviceId': 'ee380d72-bc7d-4691-9794-845f764fd3b3'}]}, {'device_arrange_id': '7517acb0-0a93-4cd3-9b89-4aa747e3ea32', 'device_arrange_name': '左奥の電気一つ', 'device_arrange_type': [], 'devices': [{'deviceName': '天井ライト12', 'colorName': 'White', 'deviceId': 'd1c918ff-09b4-4fb2-8aca-e7bebd8cc49e'}]}, {'device_arrange_id': 'eb0c17ca-5ab4-4a6d-b2eb-72974412f785', 'device_arrange_name': '奥に見える左下の電気', 'device_arrange_type': [], 'devices': [{'deviceName': 'フロアライト１', 'colorName': 'White', 'deviceId': 'a9dbc6ec-9b2f-4542-a232-39d41493d4d0'}]}, {'device_arrange_id': 'e5813fa8-3be0-4d47-bf14-6e995f2a7951', 'device_arrange_name': '目の前の棚の一番の右の列', 'device_arrange_type': [], 'devices': [{'deviceName': '棚ライト７', 'colorName': 'White', 'deviceId': '6c0bfac2-aa23-47a3-b3ac-db21253cbfae'}, {'deviceName': '棚ライト1', 'colorName': 'White', 'deviceId': '418ab535-e644-4f10-820f-058cf2057eb0'}, {'deviceName': '棚ライト4', 'colorName': 'White', 'deviceId': '80b0cdd4-de6c-4b2e-a70c-ffb663fa4812'}]}, {'device_arrange_id': 'ef939725-d1d9-4f96-8c1e-84439f9685ed', 'device_arrange_name': '棚の真ん中の列の右二つ', 'device_arrange_type': [], 'devices': []}, {'device_arrange_id': '57c4ca5c-5e47-4b6c-aa58-66d939bdaf0f', 'device_arrange_name': '後ろの壁の真ん中以外', 'device_arrange_type': [], 'devices': []}, {'device_arrange_id': '3e5150e3-4377-405c-b76b-ca076bc34f12', 'device_arrange_name': '奥の電気', 'device_arrange_type': [], 'devices': [{'deviceName': 'ランプスタンド', 'colorName': 'White', 'deviceId': '0cbbbed7-ff3c-4932-878d-63a0af564aa8'}]}, {'device_arrange_id': 'c286155d-b180-4fbe-b367-de60d489486a', 'device_arrange_name': '手前三つ青奥三つ赤', 'device_arrange_type': [], 'devices': [{'deviceName': '天井ライト5', 'colorName': 'Blue', 'deviceId': '81406953-308f-4a7d-bc6b-340c969cbc29'}, {'deviceName': '天井ライト6', 'colorName': 'Blue', 'deviceId': 'c364e75e-13c7-4a1f-a48b-c431eff17e45'}, {'deviceName': '天井ライト7', 'colorName': 'Blue', 'deviceId': '36b0460e-36d2-4f5a-88a5-5174657039f1'}, {'deviceName': '天井ライト8', 'colorName': 'Blue', 'deviceId': '1c33a40f-f48c-49f5-8383-d1c006559204'}, {'deviceName': '天井ライト4', 'colorName': 'Blue', 'deviceId': 'bce898b8-d5d6-45ac-b337-a2820b37c357'}, {'deviceName': '天井ライト7', 'colorName': 'Red', 'deviceId': '36b0460e-36d2-4f5a-88a5-5174657039f1'}, {'deviceName': '天井ライト8', 'colorName': 'Red', 'deviceId': '1c33a40f-f48c-49f5-8383-d1c006559204'}, {'deviceName': '天井ライト9', 'colorName': 'Red', 'deviceId': 'a65c2e1d-fbe8-4bf5-a49b-0ea4ad1db5c3'}]}, {'device_arrange_id': '8ec33bee-662a-44ca-8b72-d185da2f980a', 'device_arrange_n ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 print("==========  Arrange Data ========")
#       5 print(arrangeData)
# ----> 6 outputData["task_id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
outputData[0]["task_id"]="3a642a22-d8be-466d-ae3d-8ee4ae7e730f"

# %%
def evaluate_all_predictions(output_data_list, arrange_data_list):
    results = []

    # arrange_data を dict に変換して素早くアクセス
    arrange_map = {
        entry["device_arrange_id"]: [dev["deviceId"] for dev in entry["devices"]]
        for entry in arrange_data_list
    }

    for output in output_data_list:
        task_id = output.get("task_id")
        predicted_ids = [d["id"] for d in output.get("selected_devices", [])]
        ground_truth_ids = arrange_map.get(task_id)

        if ground_truth_ids is None:
            print(f"[⚠️ Warning] Ground truth not found for task_id: {task_id}")
            continue

        gt_set = set(ground_truth_ids)
        pred_set = set(predicted_ids)

        true_positives = gt_set & pred_set
        false_positives = pred_set - gt_set
        false_negatives = gt_set - pred_set

        precision = len(true_positives) / len(pred_set) if pred_set else 0
        recall = len(true_positives) / len(gt_set) if gt_set else 0

        results.append({
            "task_id": task_id,
            "ground_truth": ground_truth_ids,
            "predicted": predicted_ids,
            "true_positives": list(true_positives),
            "false_positives": list(false_positives),
            "false_negatives": list(false_negatives),
            "precision": precision,
            "recall": recall
        })

    return results

# %%
results = evaluate_all_predictions(outputData, arrangeData)
import pprint
pprint.pprint(results)
# Out:
# [{'false_negatives': ['a65c2e1d-fbe8-4bf5-a49b-0ea4ad1db5c3',
#                       'c364e75e-13c7-4a1f-a48b-c431eff17e45',
#                       'bce898b8-d5d6-45ac-b337-a2820b37c357',
#                       '81406953-308f-4a7d-bc6b-340c969cbc29',
#                       '36b0460e-36d2-4f5a-88a5-5174657039f1',
#                       '1c33a40f-f48c-49f5-8383-d1c006559204'],
#   'false_positives': ['3f613e25-0fa0-4780-9896-adcdf01474c2',
#                       '5267d97b-9929-4288-a957-15fd46185712'],
#   'ground_truth': ['a65c2e1d-fbe8-4bf5-a49b-0ea4ad1db5c3',
#                    'c364e75e-13c7-4a1f-a48b-c431eff17e45',
#                    '81406953-308f-4a7d-bc6b-340c969cbc29',
#                    'bce898b8-d5d6-45ac-b337-a2820b37c357',
#                    '36b0460e-36d2-4f5a-88a5-5174657039f1',
#                    '1c33a40f-f48c-49f5-8383-d1c006559204'],
#   'precision': 0.0,
#   'predicted': ['5267d97b-9929-4288-a957-15fd46185712',
#                 '3f613e25-0fa0-4780-9896-adcdf01474c2'],
#   'recall': 0.0,
#   'task_id': '3a642a22-d8be-466d-ae3d-8ee4ae7e730f',
#   'true_positives': []}]
