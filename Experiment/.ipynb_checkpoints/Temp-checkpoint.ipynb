# %%
import pandas as pd 
import numpy as np 


data = pd.read_csv("./SurvayResult.csv")
p1_data = data[data["ID"] == "P1"]

# %%
conditions = pd.DataFrame({
 "ConditionID" : [1,2,3,4], 
 "ConditionName" : [
     "Pointing + 空間参照", 
     "ラベル", 
     "Pointing", 
     "SpatialReasoningAgent",
 ]   
})
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: ConditionID, dtype: int64
# 0          Pointing + 空間参照
# 1                      ラベル
# 2                 Pointing
# 3    SpatialReasoningAgent
# Name: ConditionName, dtype: object
# ConditionID      None
# ConditionName    None
# dtype: object

# %%
conditions
# Out:
#    ConditionID          ConditionName
# 0            1        Pointing + 空間参照
# 1            2                    ラベル
# 2            3               Pointing
# 3            4  SpatialReasoningAgent

# %%
conditions = pd.DataFrame({
 "ConditionID" : [1,2,3,4], 
 "ConditionName" : [
     "FilterDeviceAgent + SpatialReasoningAgent", 
     "Pointing + SpatialReasoningAgent", 
     "Pointing", 
     "Labeling",
 ]
     
})
