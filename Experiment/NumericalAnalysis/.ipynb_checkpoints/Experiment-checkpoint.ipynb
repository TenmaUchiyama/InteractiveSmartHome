# %%
import os 
import subprocess

# %%
import json
import pandas as pd
import os
df = pd.read_csv("latin_square_design.csv")
index = 20
p1 = df.iloc[0]


#研究被験者の取得
participant = f"P{index+1}"
taskSet = p1["Task Set 1"]
condition_num = int(p1["Condition 1_ConditionNum"])




#ArrangeDataを取得する
with open(f"./NumericalAnalysis/ArrangeData/PreTaskArrangement{taskSet}.json", "r", encoding="utf-8") as f:
    arrangeData = json.loads(f.read())

with open(f"./NumericalAnalysis/VOICE_LOG/{participant}/{participant}_{condition_num}.json", "r", encoding="utf-8") as f:
    voice_log = json.loads(f.read())
    
with open(f"./NumericalAnalysis/RESULTS/{participant}/{participant}_{condition_num}.json", "r", encoding="utf-8") as f:
    result_data = json.loads(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 import os
# ----> 4 df = pd.read_csv("latin_square_design.csv")
#       5 index = 20
#       6 p1 = df.iloc[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latin_square_design.csv'

# %%
task_index = 11

task = voice_log[task_index]
task["taskAttempts"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 task_index = 11
# ----> 3 task = voice_log[task_index]
#       4 task["taskAttempts"]
#
# NameError: name 'voice_log' is not defined

# %%
import os 

os.getcwd()
# Out:
# 'C:\\Users\\Tenma\\Desktop\\Keio\\InteractiveSmartHome\\InteractiveSmartHome\\Experiment'

# %%
def evaluate_all_predictions(output_data_list, arrange_data_list):
    results = []

    # arrange_data を dict に変換して素早くアクセス
    arrange_map = {
        entry["device_arrange_id"]: [dev["deviceId"] for dev in entry["devices"]]
        for entry in arrange_data_list
    }

    for output in output_data_list:
        task_id = output.get("task_id")
        predicted_ids = [d["id"] for d in output.get("selected_devices", [])]
        ground_truth_ids = arrange_map.get(task_id)

        if ground_truth_ids is None:
            print(f"[⚠️ Warning] Ground truth not found for task_id: {task_id}")
            continue

        gt_set = set(ground_truth_ids)
        pred_set = set(predicted_ids)

        true_positives = gt_set & pred_set
        false_positives = pred_set - gt_set
        false_negatives = gt_set - pred_set

        precision = len(true_positives) / len(pred_set) if pred_set else 0
        recall = len(true_positives) / len(gt_set) if gt_set else 0

        results.append({
            "task_id": task_id,
            "ground_truth": ground_truth_ids,
            "predicted": predicted_ids,
            "true_positives": list(true_positives),
            "false_positives": list(false_positives),
            "false_negatives": list(false_negatives),
            "precision": precision,
            "recall": recall
        })

    return results

# %%
results = evaluate_all_predictions(outputData, arrangeData)
import pprint
pprint.pprint(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 results = evaluate_all_predictions(outputData, arrangeData)
#       2 import pprint
#       3 pprint.pprint(results)
#
# NameError: name 'evaluate_all_predictions' is not defined

# %%
import pandas as pd
import re

# CSVの読み込み
condition = pd.read_csv("latin_square_design.csv")

# 変換用マッピング
replace_map = {
    "FD+SR": "空間参照だけ",
    "Pointing": "ポインティングだけ",
    "Pointing+SR": "Pointing+空間参照",
    "Label": "ラベル"
}

# Condition列だけを対象に処理
for col in condition.columns:
    if "Condition" in col:
        # ()の中の数字を取り出し、新しい列に保存
        condition[col + "_ConditionNum"] = condition[col].str.extract(r"\((\d+)\)").astype(float)

        # ()を除いた本体部分を変換
        condition[col] = condition[col].str.replace(r"\(\d+\)", "", regex=True).str.strip()
        condition[col] = condition[col].replace(replace_map)

# 結果を表示
condition.to_csv("./latin_square_design.csv", index=False)

# %% [markdown]
# # Average Attempts

# %%
import os
import json
import pandas as pd

# データの保存先
base_dir = "./NumericalAnalysis/VOICE_LOG"
participants = [f"P{i}" for i in range(1, 22)]  # P1〜P21
conditions = [1, 2, 3, 4]

# 結果を保存するリスト
records = []

for participant in participants:
    for condition in conditions:
        file_path = os.path.join(base_dir, participant, f"{participant}_{condition}.json")
        if not os.path.exists(file_path):
            print(f"❌ Missing: {file_path}")
            continue
        
        with open(file_path, "r", encoding="utf-8") as f:
            try:
                tasks = json.load(f)
            except json.JSONDecodeError:
                print(f"❌ JSON error: {file_path}")
                continue

        total_attempts = 0
        for task in tasks:
            # taskAttemptCountが正しくない可能性もあるので、taskAttemptsのlenを使う
            task_attempts = task.get("taskAttempts", [])
            total_attempts += len(task_attempts)

        avg_attempts = total_attempts / len(tasks) if tasks else 0

        records.append({
            "participant": participant,
            "condition": condition,
            "total_attempts": total_attempts,
            "average_attempts": avg_attempts
        })

# データフレームに変換して確認
df_attempts = pd.DataFrame(records)
print(df_attempts)
# Out:
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P1\P1_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P1\P1_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P1\P1_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P1\P1_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P2\P2_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P2\P2_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P2\P2_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P2\P2_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P3\P3_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P3\P3_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P3\P3_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P3\P3_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P4\P4_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P4\P4_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P4\P4_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P4\P4_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P5\P5_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P5\P5_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P5\P5_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P5\P5_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P6\P6_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P6\P6_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P6\P6_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P6\P6_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P7\P7_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P7\P7_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P7\P7_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P7\P7_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P8\P8_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P8\P8_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P8\P8_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P8\P8_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P9\P9_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P9\P9_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P9\P9_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P9\P9_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P10\P10_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P10\P10_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P10\P10_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P10\P10_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P11\P11_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P11\P11_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P11\P11_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P11\P11_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P12\P12_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P12\P12_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P12\P12_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P12\P12_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P13\P13_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P13\P13_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P13\P13_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P13\P13_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P14\P14_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P14\P14_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P14\P14_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P14\P14_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P15\P15_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P15\P15_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P15\P15_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P15\P15_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P16\P16_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P16\P16_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P16\P16_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P16\P16_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P17\P17_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P17\P17_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P17\P17_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P17\P17_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P18\P18_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P18\P18_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P18\P18_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P18\P18_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P19\P19_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P19\P19_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P19\P19_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P19\P19_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P20\P20_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P20\P20_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P20\P20_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P20\P20_4.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P21\P21_1.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P21\P21_2.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P21\P21_3.json
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P21\P21_4.json
# Empty DataFrame
# Columns: []
# Index: []

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rcParams
import seaborn as sns
import pandas as pd

# 明示的にMeiryoフォントを指定（Windows用）
font_path = "C:/Windows/Fonts/meiryo.ttc"
font_prop = font_manager.FontProperties(fname=font_path)
rcParams['font.family'] = font_prop.get_name()

# 仮のデータ（あなたの df_attempts の groupby結果に相当）
data = {
    "condition": [1, 2, 3, 4],
    "average_attempts": [2.3, 1.3, 2.6, 1.9]
}
df = pd.DataFrame(data)

# 条件番号をラベルに変換
condition_labels = {
    1: "SpatialReference",
    2: "Pointing + SpatialReference",
    3: "Pointing",
    4: "Label"
}
df["condition_label"] = df["condition"].map(condition_labels)

# グラフ描画
plt.figure(figsize=(10, 6))
sns.barplot(x="condition_label", y="average_attempts", data=df)
plt.title("条件ごとの平均Attempt回数", fontproperties=font_prop)
plt.xlabel("条件", fontproperties=font_prop)
plt.ylabel("平均Attempt回数（1タスクあたり）", fontproperties=font_prop)
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %%
# エラーバー（95%信頼区間）付きで棒グラフを描画
import seaborn as sns 
sns.barplot(x="condition_label", y="average_attempts", data=df, capsize=.2, ci=95)
plt.ylabel("平均Attempt回数（95%信頼区間）", fontproperties=font_prop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # エラーバー（95%信頼区間）付きで棒グラフを描画
#       2 import seaborn as sns
# ----> 3 sns.barplot(x="condition_label", y="average_attempts", data=df, capsize=.2, ci=95)
#       4 plt.ylabel("平均Attempt回数（95%信頼区間）", fontproperties=font_prop)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # ElapsedTime

# %%
import os
import json
import pandas as pd

# データのパス
base_dir = "./NumericalAnalysis/VOICE_LOG"
participants = [f"P{i}" for i in range(1, 22)]
conditions = [1, 2, 3, 4]

records = []

for participant in participants:
    for condition in conditions:
        file_path = os.path.join(base_dir, participant, f"{participant}_{condition}.json")
        if not os.path.exists(file_path):
            print(f"❌ Missing: {file_path}")
            continue

        with open(file_path, "r", encoding="utf-8") as f:
            try:
                tasks = json.load(f)
            except json.JSONDecodeError:
                print(f"❌ JSON error: {file_path}")
                continue

        total_elapsed_time = 0.0
        total_task_count = 0

        for task in tasks:
            task_time = 0.0
            for attempt in task.get("taskAttempts", []):
                try:
                    task_time += float(attempt.get("taskElapsedTime", 0))
                except ValueError:
                    pass  # 変なデータは無視
            total_elapsed_time += task_time
            total_task_count += 1

        avg_task_time = total_elapsed_time / total_task_count if total_task_count > 0 else 0

        records.append({
            "participant": participant,
            "condition": condition,
            "total_time": total_elapsed_time,
            "average_task_time": avg_task_time
        })

df_time = pd.DataFrame(records)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib import font_manager, rcParams

# 明示的に日本語フォント設定（Windows用）
font_path = "C:/Windows/Fonts/meiryo.ttc"
font_prop = font_manager.FontProperties(fname=font_path)
rcParams['font.family'] = font_prop.get_name()

# ここに df_time がすでに存在している想定
# 例: df_time = pd.DataFrame(records)

# 条件番号 → 名前に変換
condition_labels = {
    1: "SpatialReference",
    2: "Pointing + SpatialReference",
    3: "Pointing",
    4: "Label"
}
df_time["condition_label"] = df_time["condition"].map(condition_labels)

# 可視化
plt.figure(figsize=(10, 6))
sns.boxplot(x="condition_label", y="average_task_time", data=df_time)
plt.title("条件ごとのタスク平均時間（秒）", fontproperties=font_prop)
plt.xlabel("条件", fontproperties=font_prop)
plt.ylabel("平均タスク時間（1タスクあたり、秒）", fontproperties=font_prop)
plt.xticks(rotation=15, fontproperties=font_prop)
plt.yticks(fontproperties=font_prop)
plt.tight_layout()
plt.show()
# Out:
# ❌ Missing: ./NumericalAnalysis/VOICE_LOG\P12\P12_3.json
