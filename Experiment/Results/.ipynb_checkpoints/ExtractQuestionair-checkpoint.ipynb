# %%
import pandas as pd

# Load the CSV file
# Assuming the first row contains the actual questions as headers
df = pd.read_csv("./ResultData/SurvayResult.csv")

# --- 定数定義 ---
CATEGORY_COLUMNS = {
    'sus':     list(range(1, 11)),   # SUS 1–10
    'tam':     list(range(11, 14)),  # TAM 11–13
    'trust':   list(range(14, 18)),  # Trust 14–17
    'trust2':  list(range(18, 29)),  # Trust2 18–28
    'nasa':    list(range(29, 35)),  # NASA-TLX 29–37
}

print("--- 質問内容 ---")
for category, q_numbers in CATEGORY_COLUMNS.items():
    print(f"\n## カテゴリ: {category.upper()}")
    print("---")
    for q_num in q_numbers:
        # The column index for the questions starts from 1 (after 'タイムスタンプ').
        # So, the column with question 1 is at index 1, question 2 at index 2, and so on.
        # This assumes your CSV structure where questions Q1-Q37 correspond to actual column positions.
        # If 'タイムスタンプ' is the first column (index 0), then Q1 is at index 1.
        # We also need to handle the case where the header might have leading/trailing spaces or special characters.
        
        # Adjusting for 0-based indexing and the 'タイムスタンプ' column
        # q_num 1 corresponds to df.columns[1], q_num 2 to df.columns[2], etc.
        column_index = q_num

        if column_index < len(df.columns):
            question_text = df.columns[column_index]
            print(f"Q{q_num}: {question_text.strip()}") # .strip() removes leading/trailing whitespace
        else:
            print(f"警告: 質問番号 {q_num} に対応するカラムがデータフレームに見つかりません。")
# Out:
# --- 質問内容 ---
#
# ## カテゴリ: SUS
# ---
# Q1: I think that I would like to use this system frequently.
# （このシステムを頻繁に使用したいと思います。）
# Q2: I found the system unnecessarily complex.
# （このシステムは不必要に複雑だと感じました。）
# Q3: I thought the system was easy to use.
# （このシステムは簡単に使えると感じました。）
# Q4: I think that I would need the support of a technical person to be able to use this system.
# （このシステムを使うには技術的なサポートが必要だと思いました。）
# Q5: I found the various functions in this system were well integrated.
# （このシステムのさまざまな機能はうまく統合されていると感じました。）
# Q6: I thought there was too much inconsistency in this system.
# （このシステムには一貫性がないと感じました。）
# Q7: I would imagine that most people would learn to use this system very quickly.
# （ほとんどの人がこのシステムをすぐに使いこなせると思います。）
# Q8: I found the system very cumbersome to use.
# （このシステムは使いづらいと感じました。）
# Q9: I felt very confident using the system.
# （このシステムを使用する際、自信を持って使えました。）
# Q10: I needed to learn a lot of things before I could get going with this system.
# （このシステムを使い始める前に、多くのことを学ぶ必要がありました。）
#
# ## カテゴリ: TAM
# ---
# Q11: Using this interaction method improved my task performance.
# （この操作方法を使うことで、タスクの効率が向上したと感じましたか？）
# Q12: I intend to use this interaction method in the future.
# （今後もこの操作方法を使いたいと思いますか？）
# Q13: I found this interaction method to be smooth and easy to execute.
# （この操作方法はスムーズに実行できましたか？）
#
# ## カテゴリ: TRUST
# ---
# Q14: The behavior of this interaction method was consistent.
# （この操作方法の動作は一貫していましたか？）
# Q15: This interaction method performed as I intended.
# （この操作方法は意図したとおりに動作しましたか？）
# Q16: I felt that this interaction method was trustworthy.
# （この操作方法は信頼できると感じましたか？）
# Q17: I was confident that this interaction method would work correctly.
# （この操作方法を使用する際、システムが適切に動作すると確信していましたか？）
#
# ## カテゴリ: TRUST2
# ---
# Q18: I felt that this system was trustworthy.
# （このシステムは信頼できると感じました。）
# Q19: I was confident that this system would function correctly.
# （このシステムが適切に動作すると確信していました。）
# Q20: The system was reliable in its responses.
# （このシステムの応答は信頼できるものでした。）
# Q21: The system behaved in a consistent manner.
# （このシステムの挙動は一貫していました。）
# Q22: I can trust this system to operate as expected.
# （このシステムは予想通りに動作すると信頼できます。）
# Q23: The system’s actions were easy to understand.
# （このシステムの動作は理解しやすかった。）
# Q24: I was able to predict how the system would respond to my actions.
# （このシステムがどのように反応するか予測できました。）
# Q25: The system provided clear feedback about its actions.
# （このシステムは、自分の動作について明確なフィードバックを提供しました。）
# Q26: The system behaved in an underhanded manner.
# （このシステムは不誠実な動作をしたと感じました。）
# Q27: The system’s actions could lead to harmful or unintended consequences.
# （このシステムの動作は、望ましくない結果や危険を引き起こす可能性があると感じました。）
# Q28: The system provides a sense of security and integrity.
# （このシステムは安全性と誠実性を提供すると感じました。）
#
# ## カテゴリ: NASA
# ---
# Q29: How mentally demanding was the task?
# （このタスクはどの程度、精神的に負担を感じましたか？）
# Q30: How physically demanding was the task?
# （このタスクはどの程度、身体的に負担を感じましたか？）
# Q31: How hurried or rushed did you feel during the task?
# （このタスクを行う際、急かされていると感じましたか？）
# Q32: How successful do you think you were in accomplishing the task?
# （このタスクを成功させることができたと感じましたか？）
# Q33: How much effort did you need to put into completing the task?
# （このタスクを完了するために、どれくらいの努力が必要でしたか？）
# Q34: How frustrated or irritated did you feel during the task?
# （このタスクを行う際、イライラやストレスを感じましたか？）

# %%
import pandas as pd

# 元のCSVを読み込み
df = pd.read_csv("SurvayResult.csv")

# index 137以降を抽出
subset_df = df.iloc[136:]   # 137行目以降すべて

# 新しいCSVとして保存
subset_df.to_csv("SurvayResult.csv", index=False)

print("✅ 新しいCSVファイル 'SurvayResult.csv' を作成しました。")
# Out:
# ✅ 新しいCSVファイル 'SurvayResult.csv' を作成しました。

# %%
import pandas as pd

# --- CSV読み込み ---
survey = pd.read_csv("SurvayResult.csv")
latin = pd.read_csv("../latin_square.csv")

# もし文字化けがある場合 (BOM付きなど)
# latin = pd.read_csv("latin_square.csv", encoding="utf-8-sig")

# --- Condition列を数値化（全角や文字を除去） ---
survey["Condition"] = (
    survey["Condition"]
    .astype(str)
    .str.replace("４", "4")
    .str.replace("３", "3")
    .str.replace("２", "2")
    .str.replace("１", "1")
    .str.extract("(\d)")
    .astype(float)
)

# --- 各被験者ごと（4行ずつ）に検証 ---
n_participants = len(survey) // 4
results = []

for i in range(n_participants):
    # 被験者ごとのsurveyデータ
    sub = survey.iloc[i*4:(i+1)*4].reset_index(drop=True)
    
    # latin_square の ConditionNum列を抽出
    latin_row = latin.iloc[i]
    latin_order = [
        latin_row["Condition 1_ConditionNum"],
        latin_row["Condition 2_ConditionNum"],
        latin_row["Condition 3_ConditionNum"],
        latin_row["Condition 4_ConditionNum"]
    ]
    
    # 一致チェック
    is_match = list(sub["Condition"]) == latin_order
    results.append({
        "Participant": latin_row["Participant"],
        "SurveyCondition": list(sub["Condition"]),
        "LatinOrder": latin_order,
        "Match": is_match
    })

# --- 結果をDataFrame化 ---
check_df = pd.DataFrame(results)

# 不一致の人を表示
print("⚠️ 一致していない被験者一覧:")
print(check_df[check_df["Match"] == False])

# 全体の一致率
print(f"\n✅ 一致率: {(check_df['Match'].sum() / len(check_df)) * 100:.1f}%")
# Out:
# ⚠️ 一致していない被験者一覧:
#    Participant       SurveyCondition    LatinOrder  Match
# 9          P10  [1.0, 4.0, 3.0, 2.0]  [2, 3, 4, 1]  False
# 21         P22  [3.0, 2.0, 4.0, 1.0]  [2, 3, 4, 1]  False
#
# ✅ 一致率: 91.7%
