# %%
import json
import pandas as pd
df = pd.read_csv("../latin_square_design.csv")

df.columns
# Out:
# Index(['Participant', 'Condition 1', 'Task Set 1', 'Condition 1_ConditionNum',
#        'Condition 2', 'Task Set 2', 'Condition 2_ConditionNum', 'Condition 3',
#        'Task Set 3', 'Condition 3_ConditionNum', 'Condition 4', 'Task Set 4',
#        'Condition 4_ConditionNum'],
#       dtype='object')

# %%
first = df.iloc[0]
participant = first["Participant"]
condition1 = first["Condition 1_ConditionNum"]
taskSet1 = first["Task Set 1"] 

condition1 = first["Condition 2_ConditionNum"]
taskSet1 = first["Task Set 2"] 

condition1 = first["Condition 3_ConditionNum"]
taskSet1 = first["Task Set 3"] 

condition1 = first["Condition 4_ConditionNum"]
taskSet1 = first["Task Set 4"]

# %%
# Out:
# 4
