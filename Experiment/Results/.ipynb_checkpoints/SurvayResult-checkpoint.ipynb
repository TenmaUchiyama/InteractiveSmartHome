# %% [markdown]
# # 関数設計

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kruskal
import scikit_posthocs as sp
import matplotlib
from scipy.stats import shapiro
import warnings
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp

warnings.filterwarnings("ignore", category=FutureWarning)

# 日本語フォント設定
matplotlib.rcParams['font.family'] = 'Meiryo'



# --- 定数定義 ---
CATEGORY_COLUMNS = {
    'sus':     list(range(1, 11)),   # SUS 1–10
    'tam':     list(range(11, 14)),  # TAM 11–13
    'method_trust':   list(range(14, 18)),  # Trust 14–17
    'system_trust':  list(range(18, 29)),  # Trust2 18–28
    'nasa':    list(range(29, 35)),  # NASA-TLX 29–37
}
PARTICIPANT_COL = 38
CONDITION_COL   = 39
INVALID_IDS     = ['0', 'TEST', 'OLD_P1',"", "OLD_P2",  "P1_OLD","P2_OLD","P3_OLD","P4_OLD","P5_OLD","P6_OLD", ]

CONDITION_MAP = {
    1: "SpatialReference",
    2: "Pointing+SpatialReference",
    3: "Pointing",
    4: "Label"
}
 # 特定のIDのみを残す場合（必要なときにコメントアウトを外す）



# --- スコア計算 ---
def calc_sus_score(raw: list[int]) -> float:
    adj = [(s - 1) if i % 2 == 0 else (5 - s) for i, s in enumerate(raw)]
    return sum(adj) * 2.5

def compute_mean(vals: list[int]) -> float:
    return np.mean(vals)

def reverse_scoring(df: pd.DataFrame) -> pd.DataFrame:
    df['system_trust'] = df['system_trust'].apply(lambda v: [6 - x if i in (8,9) else x for i, x in enumerate(v)])
    df['nasa']   = df['nasa'].apply(lambda v: [6 - x if i == 3 else x for i, x in enumerate(v)])
    return df

# --- 統計検定用 ---
def run_kruskal(label: str, df: pd.DataFrame) -> tuple[float, float]:
    groups = [df[df['condition'] == c][label] for c in CONDITION_MAP.values()]
    return kruskal(*groups)

def check_normality(label: str, df: pd.DataFrame):
    print(f"\n🔍 正規性の検定（Shapiro-Wilk）: {label}")
    for cond in CONDITION_MAP.values():
        vals = df[df['condition'] == cond][label].dropna()  # ← NaNを除く
        n = len(vals)
        if n < 3:
            print(f"{label} - {cond}: ⚠ データ数不足（{n} 件）→ 検定スキップ")
            continue
        try:
            stat, p = shapiro(vals)
            mark = "✅ 正規性あり" if p > 0.05 else "❌ 正規性なし"
            print(f"{label} - {cond}: W={stat:.3f}, p={p:.4f} {mark}")
        except Exception as e:
            print(f"{label} - {cond}: ⚠ 検定失敗 ({e})")


# --- データ読み込み & 前処理 ---

def load_and_preprocess(filepath: str) -> pd.DataFrame:
    df = pd.read_csv(filepath, encoding='utf-8')


    
    # 参加者ID・条件情報の処理
    df['participant_id'] = df.iloc[:, PARTICIPANT_COL].astype(str)
    df['condition'] = df.iloc[:, CONDITION_COL].astype(int)

    # 無効なID除外
    df = df[~df['participant_id'].isin(INVALID_IDS)]
 
    print(len(df["participant_id"]))
    # df = df[df['participant_id'].isin(["P3"])]
    print(len(df))
    df = df.reset_index(drop=True)

    # SUS, TAM, Trust, Trust2, NASA などのスコア用リスト列を作成
    for key, cols in CATEGORY_COLUMNS.items():
        df[key] = df.iloc[:, cols].apply(lambda r: r.astype(int).tolist(), axis=1)
    
    
    return df

def kruskal_eta_squared(H: float, k: int, n: int) -> float:
    return (H - k + 1) / (n - k)

# --- メイン ---
def main():
    # データ読み込み・前処理
    df = load_and_preprocess('SurvayResult.csv')
    df = reverse_scoring(df)

    # スコア DataFrame 作成
    metrics = {
        'SUS':     ('sus',    calc_sus_score, 0, 100),
        'TAM':     ('tam',    compute_mean,   1,   7),
        'MethodTrust':   ('method_trust',  compute_mean,   1,   7),
        'SystemTrust':  ('system_trust', compute_mean,   1,   7),
        'NASA-TLX':('nasa',   compute_mean,   1,   7),
    }
    dfs = {}
    for name, (key, func, ymin, ymax) in metrics.items():
        dfs[name] = pd.DataFrame({
            'participant_id': df['participant_id'],
            'condition':      df['condition'],
            name:              df[key].apply(func)
        })

    # 条件ラベル適用
    ordered_conditions = ["SpatialReference", "Pointing+SpatialReference", "Pointing", "Label"]
    for dfm in dfs.values():
        dfm['condition'] = dfm['condition'].map(CONDITION_MAP)

    # 🔽 条件の並び順を明示的に指定
    ordered_conditions = ["SpatialReference", "Pointing+SpatialReference", "Pointing", "Label"]
    for dfm in dfs.values():
        dfm['condition'] = pd.Categorical(dfm['condition'], categories=ordered_conditions, ordered=True)
    # 1. 基本プロット: 箱ひげ＋スウォーム & 平均±SEバー
    fig1, axes1 = plt.subplots(len(metrics), 2, figsize=(14, 5*len(metrics)))
    for i, (name, dfm) in enumerate(dfs.items()):
        ymin, ymax = metrics[name][2], metrics[name][3]
        # 箱ひげ＋スウォーム
        ax = axes1[i, 0]
        sns.boxplot(data=dfm, x='condition', y=name, palette='pastel', ax=ax)
        sns.swarmplot(data=dfm, x='condition', y=name, color='k', alpha=0.6, ax=ax)
        ax.set(title=f"{name} の条件別比較", ylim=(ymin, ymax))
        # 平均±SEバー
        ax2 = axes1[i, 1]
        means = dfm.groupby('condition')[name].mean()
        sems  = dfm.groupby('condition')[name].sem()
        ax2.bar(means.index, means, yerr=sems, capsize=5)
        ax2.set(title=f"{name} 平均 ± SE", ylim=(ymin, ymax))
    plt.tight_layout(); plt.suptitle('条件別ユーザビリティ・受容性評価', y=1.02)
    plt.savefig('survey_plots.png', dpi=300)

    # 2. 統計検定 & 結果表示
    print()
    stats = {}
    for name in ['SUS','TAM','MethodTrust','SystemTrust']:
        stat, p = run_kruskal(name, dfs[name])
        has_significance = p < 0.05
        mark = "✅ 有意差あり" if has_significance else "❌ 有意差なし"
        print(f"{name}: H={stat:.3f}, p={p} {mark}")
        stats[name] = (stat, p)

        # 有意差があればDunn事後検定
        if has_significance:
            print("→ Dunnの事後検定（Bonferroni補正）結果:")
            print(sp.posthoc_dunn(dfs[name], val_col=name, group_col='condition', p_adjust='bonferroni'))
            print()
    # 各条件（行） × 各指標（列）の平均スコアを作成
    summary = pd.DataFrame(
    {
        metric: [
            dfs[metric][dfs[metric]['condition'] == cond][metric].mean()
            for cond in CONDITION_MAP.values()
        ]
        for metric in ['SUS', 'TAM', 'MethodTrust', 'SystemTrust']
    },
        index=CONDITION_MAP.values()  # 行名を条件のラベルに
    )

    # 小数点以下2桁で丸めて表示
    print(summary.round(2))

    # 4. 効果量 η² を表示
    print("\n効果量 η²（Kruskal-Wallis）:")
    for name in ['SUS','TAM','Trust','SystemTrust']:
        H, p = stats[name]
        n = len(dfs[name])  # データ数（NaN除外してないならOK）
        k = dfs[name]['condition'].nunique()
        eta2 = kruskal_eta_squared(H, k, n)
        print(f"{name}: η² = {eta2:.3f}")

    
    run_friedman_nemenyi(dfs)

    # 3. 統計結果付きボックスプロット
    fig2, axes2 = plt.subplots(2, 2, figsize=(12, 10))
    for ax, name in zip(axes2.flat, ['SUS','TAM','MethodTrust','SystemTrust']):
        dfm = dfs[name]
        stat, p = stats[name]
        sns.boxplot(data=dfm, x='condition', y=name, palette='pastel', ax=ax)
        ax.set_title(f"{name} (H={stat:.2f}, p={p})")
        ax.set_xlabel(''); ax.set_ylabel(name)
    plt.tight_layout(); plt.suptitle('統計検定結果付き分布図', y=1.02)
    plt.savefig('stats_boxplots.png', dpi=300)
    plt.show()
# Out:
# 96
# 96
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sus1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 61
#      55 ax = axes[i]
#      57 # ★ここを修正★
#      58 # Conditionごと、回答(1-5)ごとに人数を集計
#      59 crosstab_df = pd.crosstab(
#      60     df_result['Condition'],    # 行：条件
# ---> 61     df_result[q_col]           # 列：各sus質問の回答値
#      62 )
#      64 # 回答1～5を必ず並べる
#      65 crosstab_df = crosstab_df.reindex(columns=[1, 2, 3, 4, 5], fill_value=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'sus1'

# %%
def run_friedman_nemenyi(dfs):
    print("\n=== 🧪 Friedman Test & Nemenyi Post-hoc ===")
    nemenyi_results = {}  # ← 追加：p値マトリクス格納用

    for metric in ['SUS', 'TAM', 'MethodTrust', 'SystemTrust', "NASA-TLX" ]:
        dfm = dfs[metric]
        wide_df = dfm.pivot(index='participant_id', columns='condition', values=metric)
        wide_df = wide_df.dropna()

        try:
            stat, p = friedmanchisquare(*[wide_df[col] for col in wide_df.columns])
            mark = "✅ 有意差あり" if p < 0.05 else "❌ 有意差なし"
            print(f"{metric}: χ²={stat:.3f}, p={p:.4f} {mark}")

            if p < 0.05:
                nemenyi_df = sp.posthoc_nemenyi_friedman(wide_df)
                nemenyi_results[metric] = nemenyi_df  # ← 保存
                # print("→ Nemenyi post-hoc 検定結果（p値マトリクス）:")
                # print(nemenyi_df.round(4))
                # print()
        except Exception as e:
            print(f"{metric}: ⚠ エラー - {e}")
    
    return nemenyi_results  # ← 結果を返す
def visualize_nemenyi_heatmaps(nemenyi_results: dict):
    import matplotlib.pyplot as plt
    import seaborn as sns

    fig, axes = plt.subplots(2, 2, figsize=(16, 14))
    axes = axes.flatten()

    for ax, (metric, df) in zip(axes, nemenyi_results.items()):
        sns.heatmap(df, annot=True, fmt=".4f", cmap="coolwarm_r",
                    cbar_kws={"label": "p値"}, linewidths=0.5, square=True, ax=ax)
        ax.set_title(f"{metric} のNemenyi検定結果")

    plt.suptitle("Nemenyi事後検定結果ヒートマップ（各指標）", fontsize=18, y=1.02)
    plt.tight_layout()
    plt.savefig("nemenyi_heatmaps.png", dpi=300)
    plt.show()

# %%
main()
# Out:
# 88
# 88
#
# SUS: H=34.468, p=1.5782178928105522e-07 ✅ 有意差あり
# → Dunnの事後検定（Bonferroni補正）結果:
#                            SpatialReference  Pointing+SpatialReference  \
# SpatialReference                   1.000000               1.930567e-03
# Pointing+SpatialReference          0.001931               1.000000e+00
# Pointing                           0.089717               1.000000e+00
# Label                              0.501103               5.966122e-07
#
#                            Pointing         Label
# SpatialReference           0.089717  5.011028e-01
# Pointing+SpatialReference  1.000000  5.966122e-07
# Pointing                   1.000000  1.875066e-04
# Label                      0.000188  1.000000e+00
#
# TAM: H=30.119, p=1.302481135422578e-06 ✅ 有意差あり
# → Dunnの事後検定（Bonferroni補正）結果:
#                            SpatialReference  Pointing+SpatialReference  \
# SpatialReference                   1.000000                   0.000287
# Pointing+SpatialReference          0.000287                   1.000000
# Pointing                           1.000000                   0.035208
# Label                              1.000000                   0.000001
#
#                            Pointing     Label
# SpatialReference           1.000000  1.000000
# Pointing+SpatialReference  0.035208  0.000001
# Pointing                   1.000000  0.085650
# Label                      0.085650  1.000000
#
# MethodTrust: H=34.734, p=1.3864271618218737e-07 ✅ 有意差あり
# → Dunnの事後検定（Bonferroni補正）結果:
#                            SpatialReference  Pointing+SpatialReference  \
# SpatialReference                   1.000000                   0.000012
# Pointing+SpatialReference          0.000012                   1.000000
# Pointing                           0.000001                   1.000000
# Label                              0.104479                   0.105324
#
#                            Pointing     Label
# SpatialReference           0.000001  0.104479
# Pointing+SpatialReference  1.000000  0.105324
# Pointing                   1.000000  0.026687
# Label                      0.026687  1.000000
#
# SystemTrust: H=34.571, p=1.5009608366333268e-07 ✅ 有意差あり
# → Dunnの事後検定（Bonferroni補正）結果:
#                            SpatialReference  Pointing+SpatialReference  \
# SpatialReference                   1.000000                   0.000002
# Pointing+SpatialReference          0.000002                   1.000000
# Pointing                           0.000005                   1.000000
# Label                              0.052916                   0.068957
#
#                            Pointing     Label
# SpatialReference           0.000005  0.052916
# Pointing+SpatialReference  1.000000  0.068957
# Pointing                   1.000000  0.131826
# Label                      0.131826  1.000000
#
#                              SUS   TAM  MethodTrust  SystemTrust
# SpatialReference           58.52  4.00         2.90         3.02
# Pointing+SpatialReference  81.14  5.88         4.38         4.42
# Pointing                   74.66  4.61         4.45         4.36
# Label                      45.80  3.29         3.77         3.81
#
# 効果量 η²（Kruskal-Wallis）:
# SUS: η² = 0.375
# TAM: η² = 0.323
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 main()
#
# Cell In[7], line 187, in main()
#     185 print("\n効果量 η²（Kruskal-Wallis）:")
#     186 for name in ['SUS','TAM','Trust','SystemTrust']:
# --> 187     H, p = stats[name]
#     188     n = len(dfs[name])  # データ数（NaN除外してないならOK）
#     189     k = dfs[name]['condition'].nunique()
#
# KeyError: 'Trust'

# %%
df['condition'] = df['condition'].map(CONDITION_MAP)

# %% [markdown]
# # データ読み込み・前処理

# %%
# データ読み込み・前処理
df = load_and_preprocess('SurvayResult.csv')
df = reverse_scoring(df)

INVALID_IDS     = ['0', 'TEST', 'OLD_P1',"", "OLD_P2",  "P1_OLD","P2_OLD","P3_OLD","P4_OLD","P5_OLD","P6_OLD", ]
df = df[~df['participant_id'].isin(INVALID_IDS)]
CATEGORY_COLUMNS = {
    'sus':     list(range(1, 11)),   # SUS 1–10
    'tam':     list(range(11, 14)),  # TAM 11–13
    'method_trust':   list(range(14, 18)),  # Trust 14–17
    'system_trust':  list(range(18, 29)),  # Trust2 18–28
    'nasa':    list(range(29, 35)),  # NASA-TLX 29–37
}
survay_score  = {}
survay_questions = {}

for key, cols in CATEGORY_COLUMNS.items():
    # スライスは cols[0] から cols[-1]+1 まで（末尾を含むには+1が必要）
    cleaned_columns = [re.sub(r'\n（.*?）', '', col) for col in df.columns[cols[0]:cols[-1]+1]]
    survay_questions[key] = cleaned_columns


for key, cols in CATEGORY_COLUMNS.items():
    survay_score[key] = df.iloc[:, cols].apply(lambda r: r.astype(int).tolist(), axis=1)




# スコア DataFrame 作成
metrics = {
    'SUS':     ('sus',    calc_sus_score, 0, 100),
    'TAM':     ('tam',    compute_mean,   1,   7),
    'MethodTrust':   ('method_trust',  compute_mean,   1,   7),
    'SystemTrust':  ('system_trust', compute_mean,   1,   7),
    'NASA-TLX':('nasa',   compute_mean,   1,   7),
}
dfs = {}
for name, (key, func, ymin, ymax) in metrics.items():
    dfs[name] = pd.DataFrame({
        'participant_id': df['participant_id'],
        'condition':      df['condition'],
        name:              df[key].apply(func)
    })

# 条件ラベル適用
ordered_conditions = ["SpatialReference", "Pointing+SpatialReference", "Pointing", "Label"]
for dfm in dfs.values():
    dfm['condition'] = dfm['condition'].map(CONDITION_MAP)
# Out:
# 96
# 96

# %% [markdown]
# # 結果の可視化

# %%
# 🔽 条件の並び順を明示的に指定
ordered_conditions = ["SpatialReference", "Pointing+SpatialReference", "Pointing", "Label"]
for dfm in dfs.values():
    dfm['condition'] = pd.Categorical(dfm['condition'], categories=ordered_conditions, ordered=True)
# 1. 基本プロット: 箱ひげ＋スウォーム & 平均±SEバー
fig1, axes1 = plt.subplots(len(metrics), 2, figsize=(14, 5*len(metrics)))
for i, (name, dfm) in enumerate(dfs.items()):
    ymin, ymax = metrics[name][2], metrics[name][3]
    # 箱ひげ＋スウォーム
    ax = axes1[i, 0]
    sns.boxplot(data=dfm, x='condition', y=name, palette='pastel', ax=ax)
    sns.swarmplot(data=dfm, x='condition', y=name, color='k', alpha=0.6, ax=ax)
    ax.set(title=f"{name} の条件別比較", ylim=(ymin, ymax))
    # 平均±SEバー
    ax2 = axes1[i, 1]
    means = dfm.groupby('condition')[name].mean()
    sems  = dfm.groupby('condition')[name].sem()
    ax2.bar(means.index, means, yerr=sems, capsize=5)
    ax2.set(title=f"{name} 平均 ± SE", ylim=(ymin, ymax))
plt.tight_layout(); plt.suptitle('条件別ユーザビリティ・受容性評価', y=1.02)
plt.savefig('survey_plots.png', dpi=300)

# %% [markdown]
# # Friedman統計検定・結果

# %%
nemenyi_results = run_friedman_nemenyi(dfs)  # ← 結果を受け取る
visualize_nemenyi_heatmaps(nemenyi_results)  # ← 可視化する
# Out:
# === 🧪 Friedman Test & Nemenyi Post-hoc ===
# SUS: χ²=39.806, p=0.0000 ✅ 有意差あり
# TAM: χ²=28.019, p=0.0000 ✅ 有意差あり
# MethodTrust: χ²=34.687, p=0.0000 ✅ 有意差あり
# SystemTrust: χ²=37.900, p=0.0000 ✅ 有意差あり
# NASA-TLX: χ²=28.397, p=0.0000 ✅ 有意差あり

# %%
print(survay_score["sus"])
# Out:
# 0     [2, 1, 4, 1, 5, 1, 5, 2, 2, 1]
# 1     [5, 1, 5, 1, 5, 1, 5, 1, 5, 1]
# 2     [4, 4, 5, 1, 5, 1, 5, 2, 5, 1]
# 3     [4, 1, 5, 1, 5, 1, 3, 2, 4, 5]
# 4     [4, 2, 4, 3, 4, 1, 4, 3, 4, 4]
#                    ...
# 91    [5, 1, 5, 2, 5, 2, 5, 2, 5, 2]
# 92    [2, 2, 4, 2, 3, 2, 3, 2, 4, 2]
# 93    [2, 4, 2, 4, 3, 4, 2, 4, 2, 3]
# 94    [4, 2, 4, 2, 4, 2, 4, 2, 4, 2]
# 95    [4, 2, 5, 2, 3, 2, 5, 2, 4, 2]
# Length: 96, dtype: object

# %%
# df_result は既に読み込み＆前処理済みとします

# Condition の値と DataFrame 名の対応例
# 1: DeviceFilterAgent + SpatialReasoningAgent → df_spatial
# 2: Pointing + SpatialReasoningAgent      → df_ptSpatial
# 3: Pointing Only                         → df_point
# 4: Label                                 → df_label

df_spatial    = df_result[df_result['Condition'] == 1].copy()
df_ptSpatial  = df_result[df_result['Condition'] == 2].copy()
df_point      = df_result[df_result['Condition'] == 3].copy()
df_label      = df_result[df_result['Condition'] == 4].copy()

# 中身の行数を確認しておく
print("df_spatial   :", len(df_spatial), "件")
print("df_ptSpatial :", len(df_ptSpatial), "件")
print("df_point     :", len(df_point), "件")
print("df_label     :", len(df_label), "件")
# Out:
# df_spatial   : 24 件
# df_ptSpatial : 24 件
# df_point     : 24 件
# df_label     : 24 件
# タイムスタンプ                                                                                                                                                              2025/06/20 19:39:03
# I think that I would like to use this system frequently.\n（このシステムを頻繁に使用したいと思います。）                                                                                                      2
# I found the system unnecessarily complex.\n（このシステムは不必要に複雑だと感じました。）                                                                                                                     1
# I thought the system was easy to use.\n（このシステムは簡単に使えると感じました。）                                                                                                                          4
# I think that I would need the support of a technical person to be able to use this system.\n（このシステムを使うには技術的なサポートが必要だと思いました。）                                                           1
# I found the various functions in this system were well integrated.\n（このシステムのさまざまな機能はうまく統合されていると感じました。）                                                                                 5
# I thought there was too much inconsistency in this system.\n（このシステムには一貫性がないと感じました。）                                                                                                    1
# I would imagine that most people would learn to use this system very quickly.\n（ほとんどの人がこのシステムをすぐに使いこなせると思います。）                                                                         5
# I found the system very cumbersome to use.\n（このシステムは使いづらいと感じました。）                                                                                                                      2
# I felt very confident using the system.\n（このシステムを使用する際、自信を持って使えました。）                                                                                                                   2
# I needed to learn a lot of things before I could get going with this system.\n（このシステムを使い始める前に、多くのことを学ぶ必要がありました。）                                                                       1
#   Using this interaction method improved my task performance.\n（この操作方法を使うことで、タスクの効率が向上したと感じましたか？）                                                                                      5
#   I intend to use this interaction method in the future.\n（今後もこの操作方法を使いたいと思いますか？）                                                                                                      5
#   I found this interaction method to be smooth and easy to execute.\n（この操作方法はスムーズに実行できましたか？）                                                                                           5
#   The behavior of this interaction method was consistent.\n（この操作方法の動作は一貫していましたか？）                                                                                                      5
#   This interaction method performed as I intended.\n（この操作方法は意図したとおりに動作しましたか？）                                                                                                          5
#   I felt that this interaction method was trustworthy.\n（この操作方法は信頼できると感じましたか？）                                                                                                         2
#   I was confident that this interaction method would work correctly.\n（この操作方法を使用する際、システムが適切に動作すると確信していましたか？）                                                                           4
#    I felt that this system was trustworthy.\n（このシステムは信頼できると感じました。）                                                                                                                     2
#   I was confident that this system would function correctly.\n（このシステムが適切に動作すると確信していました。）                                                                                               2
#   The system was reliable in its responses.\n（このシステムの応答は信頼できるものでした。）                                                                                                                   5
#   The system behaved in a consistent manner.\n（このシステムの挙動は一貫していました。）                                                                                                                    5
#   I can trust this system to operate as expected.\n（このシステムは予想通りに動作すると信頼できます。）                                                                                                          2
#   The system’s actions were easy to understand.\n（このシステムの動作は理解しやすかった。）                                                                                                                 5
#    I was able to predict how the system would respond to my actions.\n（このシステムがどのように反応するか予測できました。）                                                                                      5
#   The system provided clear feedback about its actions.\n（このシステムは、自分の動作について明確なフィードバックを提供しました。）                                                                                         5
#   The system behaved in an underhanded manner.\n（このシステムは不誠実な動作をしたと感じました。）                                                                                                              1
#   The system’s actions could lead to harmful or unintended consequences.\n（このシステムの動作は、望ましくない結果や危険を引き起こす可能性があると感じました。）                                                                  4
#   The system provides a sense of security and integrity.\n（このシステムは安全性と誠実性を提供すると感じました。）                                                                                                 5
# How mentally demanding was the task?\n（このタスクはどの程度、精神的に負担を感じましたか？）                                                                                                                      7
# How physically demanding was the task?\n（このタスクはどの程度、身体的に負担を感じましたか？）                                                                                                                    7
# How hurried or rushed did you feel during the task?\n（このタスクを行う際、急かされていると感じましたか？）                                                                                                       0
# How successful do you think you were in accomplishing the task?\n（このタスクを成功させることができたと感じましたか？）                                                                                          10
# How much effort did you need to put into completing the task?\n（このタスクを完了するために、どれくらいの努力が必要でしたか？）                                                                                        3
# How frustrated or irritated did you feel during the task?\n（このタスクを行う際、イライラやストレスを感じましたか？）                                                                                               0
# How burdensome did you find gaze movement or searching during the task?\n（このタスクの間、視線の移動や検索はどの程度負担になりましたか？）                                                                             6
# To what extent did you need to adjust your body position or posture to complete the task?\n（このタスクを完了するために、どの程度、体の向きを変更する必要がありましたか？）                                                    9
# How much burden did you feel from moving or repositioning yourself during the task?\n（このタスクの間、移動や再配置による負担をどの程度感じましたか？）                                                                 7
# ID                                                                                                                                                                                    P1
# Condition                                                                                                                                                                              1
# Free Description (自由記述)                                                                                                                言葉だけで指定するのは、複数選択するときに難しい。このパターンだと、言語で指定すのをすごく不...
# 年齢（Age）                                                                                                                                                                              NaN
# 性別（Gender）                                                                                                                                                                           NaN
#   Do you own a smart speaker?  （スマートスピーカーを所有していますか？）                                                                                                                                 NaN
# If yes, which type?(所有している場合は、機種を)                                                                                                                                                   NaN
# How have you operated smart home devices? (スマート家電の操作方法として使ったことがあるもの)                                                                                                                 NaN
# Do you regularly use smart home devices?　(スマート家電を日常的に使っていますか？)                                                                                                                       NaN
# 列 40                                                                                                                                                                                 NaN
# participant_id                                                                                                                                                                        P1
# condition                                                                                                                                                                              1
# sus                                                                                                                                                       [2, 1, 4, 1, 5, 1, 5, 2, 2, 1]
# tam                                                                                                                                                                            [5, 5, 5]
# method_trust                                                                                                                                                                [5, 5, 2, 4]
# system_trust                                                                                                                                           [2, 2, 5, 5, 2, 5, 5, 5, 5, 2, 5]
# nasa                                                                                                                                                                 [7, 7, 0, -4, 3, 0]
# Name: 0, dtype: object

# %%
CATEGORY_COLUMNS = {
    'sus':     list(range(1, 11)),   # SUS 1–10
    'tam':     list(range(11, 14)),  # TAM 11–13
    'method_trust':   list(range(14, 18)),  # Trust 14–17
    'system_trust':  list(range(18, 29)),  # Trust2 18–28
    'nasa':    list(range(29, 35)),  # NASA-TLX 29–37
}
survay_score  = {}
survay_questions = {}

for key, cols in CATEGORY_COLUMNS.items():
    # スライスは cols[0] から cols[-1]+1 まで（末尾を含むには+1が必要）
    cleaned_columns = [re.sub(r'\n（.*?）', '', col) for col in df.columns[cols[0]:cols[-1]+1]]
    survay_questions[key] = cleaned_columns

    

for key, cols in CATEGORY_COLUMNS.items():
    survay_score[key] = df.iloc[:, cols].apply(lambda r: r.astype(int).tolist(), axis=1)

# %%
# Out:
# ['I think that I would like to use this system frequently.',
#  'I found the system unnecessarily complex.',
#  'I thought the system was easy to use.',
#  'I think that I would need the support of a technical person to be able to use this system.',
#  'I found the various functions in this system were well integrated.',
#  'I thought there was too much inconsistency in this system.',
#  'I would imagine that most people would learn to use this system very quickly.',
#  'I found the system very cumbersome to use.',
#  'I felt very confident using the system.']
