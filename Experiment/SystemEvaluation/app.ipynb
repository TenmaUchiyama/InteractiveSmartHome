# %%
import sys
import json
sys.path.append("C:/Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace")

# その後で import
from no_tool_agent_runner import getSpatialRunner


with open("./Shelf/shelf_single_no_color.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

with open("./Shelf/Shelf.json", "r", encoding="utf-8") as f:
    shelf_data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 sys.path.append("C:/Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace")
#       5 # その後で import
# ----> 6 from no_tool_agent_runner import getSpatialRunner
#       9 with open("./Shelf/shelf_single_no_color.json", "r", encoding="utf-8") as f:
#      10     tasks = json.load(f)
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\no_tool_agent_runner.py:2
#       1 from io import BytesIO
# ----> 2 from agents.label_agent.label_node import label_agent_node, label_tool_node
#       3 from langgraph.graph import Graph, START, END, StateGraph
#       4 from IPython.display import Image, display
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\agents\label_agent\label_node.py:9
#       6 from sr_app_types.no_tool_agent_types import LabelState
#       7 import os, json
# ----> 9 from agents.device_operator_agent.operator_tool import operateDevice
#      13 # プロンプトと全デバイスの読み込み
#      14 script_dir = os.path.dirname(os.path.abspath(__file__))
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\agents\device_operator_agent\operator_tool.py:22
#      17     intensity: int = Field(..., description="Brightness level from 0 to 60.")
#      18     color: RGBColor = Field(..., description="Color as RGB values.")
# ---> 22 deviceOperator = DeviceOperator()
#      23 testOperator = TestOperator()
#      25 is_simulation = True
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\utils\communication\DeviceOperator.py:22, in DeviceOperator.__init__(self)
#      17 load_dotenv("../.env")
#      18 self.switchbot = SwitchBotOperator(
#      19     token=os.getenv("SB_TOKEN"),
#      20     secret=os.getenv("SB_SECRET")
#      21 )
# ---> 22 self.test_operator = TestOperator()
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\utils\communication\TestOperator.py:9, in TestOperator.__init__(self)
#       7 def __init__(self):
# ----> 9     self.request_url = os.getenv("XR_SERVER_API") + "/device/operate"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'
