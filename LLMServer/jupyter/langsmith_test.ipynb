# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-4o", verbose=True)

# %%
res= llm.invoke("こんにちは！あなたは何ができるのですか？")

# %%
res
# Out:
# AIMessage(content='こんにちは！私はAIアシスタントで、さまざまな情報提供や質問への回答、文章の作成、アイデアのブレインストーミング、学習支援、簡単な翻訳などをサポートできます。何かお手伝いできることがありますか？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 19, 'total_tokens': 88, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_b7faba9ef5', 'finish_reason': 'stop', 'logprobs': None}, id='run-731b51e8-1400-490a-a97d-fa3f95e568dd-0', usage_metadata={'input_tokens': 19, 'output_tokens': 69, 'total_tokens': 88, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# Out:
# {'status': 'success', 'devices': [{'id': '1020e40e-efd8-45fc-9209-095079fc27ce', 'name': 'テレビライト', 'position': {'x': 1.48685515, 'y': -0.74, 'z': -0.0762193}, 'distance_from_furniture': 1.6625725}, {'id': 'c7779e93-c77c-49b6-8ad5-14c122b66301', 'name': 'テレビライト２', 'position': {'x': -1.25031161, 'y': -0.76, 'z': -0.922471166}, 'distance_from_furniture': 1.72969139}, {'id': '6784852e-595b-4d67-8ea8-1b9f170c642b', 'name': '天井ライト11', 'position': {'x': 0.220359072, 'y': 1.95, 'z': -1.53541958}, 'distance_from_furniture': 2.49170065}, {'id': '965f704f-6f42-4b52-9e50-d421b35cdb08', 'name': 'フロアライト１', 'position': {'x': -2.05367351, 'y': -1.397, 'z': -1.52672756}, 'distance_from_furniture': 2.91548967}]}

# %%
# Out:
# {'status': 'success', 'devices': [{'id': '0559d5f4-e55e-4cd9-bb63-f272dc936789', 'name': 'テレビライト', 'position': {'x': 0.4636383, 'y': -0.7315315, 'z': 1.41917169}, 'distance_from_furniture': 1.6625725}, {'id': '328878fa-1aca-46e3-9865-25cf99a4ae53', 'name': 'テレビライト２', 'position': {'x': 0.5647068, 'y': -0.7668779, 'z': -1.44389629}, 'distance_from_furniture': 1.72969139}, {'id': '40a8b93b-4087-4f82-a9db-b6b95400fd59', 'name': '天井ライト11', 'position': {'x': 1.5362978, 'y': 1.95156336, 'z': -0.199401975}, 'distance_from_furniture': 2.49170065}, {'id': 'b5a69c6c-6d4d-464a-ac24-aa3a38bf806f', 'name': 'フロアライト１', 'position': {'x': 0.9389405, 'y': -1.40829229, 'z': -2.3738544}, 'distance_from_furniture': 2.91548967}, {'id': 'd9c63d82-c62f-4536-b9d0-71d45274f965', 'name': '天井ライト10', 'position': {'x': 1.46611929, 'y': 1.962223, 'z': 1.78933132}, 'distance_from_furniture': 3.033403}, {'id': 'a734c99e-b608-4ce5-9dfb-fd0a17c8fc35', 'name': '天井ライト12', 'position': {'x': 1.60718107, 'y': 1.94079661, 'z': -2.20812321}, 'distance_from_furniture': 3.35045242}, {'id': 'b9835349-7175-4f23-a5b1-09078b122142', 'name': '天井ライト6', 'position': {'x': 3.52905488, 'y': 1.955333, 'z': -0.129101992}, 'distance_from_furniture': 4.03661}, {'id': 'a41aaac7-2f96-4553-97ff-90b0648c22ee', 'name': '天井ライト9', 'position': {'x': 3.45887661, 'y': 1.96599269, 'z': 1.85963118}, 'distance_from_furniture': 4.39171743}, {'id': '5c5f210b-fa00-4395-b7ab-fdd59d084b1d', 'name': '天井ライト3', 'position': {'x': 3.59993839, 'y': 1.94456625, 'z': -2.137823}, 'distance_from_furniture': 4.61640358}, {'id': '36fbe019-ca96-4c38-af18-90396579c227', 'name': 'テーブルライト', 'position': {'x': 4.744896, 'y': -0.752483845, 'z': -0.09970224}, 'distance_from_furniture': 4.80522728}], 'furniture_data': {'position': {'x': -5.72876, 'y': 0.277666271, 'z': 1.55047238}, 'furnitureShape': {'width': 0.07806587, 'height': 1.22375536, 'depth': 2.06155682}, 'distance_from_user': 5.94135952, 'id': 'afdc8c82-914d-43d5-8837-0959e1ba7ff1', 'name': 'テレビ', 'FurnitureType': 'TV'}}
