# %%
import json


with open("../../Experiment/SystemEvaluation/Shelf/shelf_single_no_color.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

with open("../../Experiment/SystemEvaluation/Shelf/Shelf.json", "r", encoding="utf-8") as f:
    shelf_data = json.load(f)

# %%
from no_tool_agent_runner import getSpatialRunner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from no_tool_agent_runner import getSpatialRunner
#
# ModuleNotFoundError: No module named 'no_tool_agent_runner'

# %%
import sys
import json


sys.path.append("C:/Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace")
from dotenv import load_dotenv
load_dotenv("../../LLMServer/.env")
# その後で import
from no_tool_agent_runner import getSpatialRunner


with open("./Shelf/shelf_single_no_color.json", "r", encoding="utf-8") as f:
    tasks = json.load(f)

with open("./Shelf/Shelf.json", "r", encoding="utf-8") as f:
    shelf_data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 9
#       7 load_dotenv("../../LLMServer/.env")
#       8 # その後で import
# ----> 9 from no_tool_agent_runner import getSpatialRunner
#      12 with open("./Shelf/shelf_single_no_color.json", "r", encoding="utf-8") as f:
#      13     tasks = json.load(f)
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\no_tool_agent_runner.py:8
#       6 from sr_app_types.node_types import NODE
#       7 from agents.device_filter_agent.no_tool_filter_nodes import filter_preprocess, filter_agent_node, filter_tool_node
# ----> 8 from agents.spatial_reasoning_agent.no_tool_spatial_node import pointing_spatial_node, sr_agent_node, sr_preprocess_node, sr_tool_node, system_post_process_node
#       9 from agents.pointing_agent.point_node import pointing_agent_node, pointing_tool_node
#      15 def getSystemRunner():
#
# File C:\Users/Tenma/Desktop/Keio/InteractiveSmartHome/InteractiveSmartHome/LLMServer/workspace\agents\spatial_reasoning_agent\no_tool_spatial_node.py:20
#      17 language = os.getenv("VOICE_LANG", "en").strip() if os.getenv("VOICE_LANG") else "en"
#      18 file_path = os.path.join(script_dir, "prompts", "jp_spatial_msg.txt" if language == "ja" else "prompts/no_tool_spatial_msg.txt")
# ---> 20 with open(file_path, "r", encoding="utf-8") as f:
#      21     spatial_message = SystemMessage(f.read())
#      23 # --- コールバックと LLM 設定 ---
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Tenma\\Desktop\\Keio\\InteractiveSmartHome\\InteractiveSmartHome\\LLMServer\\workspace\\agents\\spatial_reasoning_agent\\prompts\\prompts/no_tool_spatial_msg.txt'
