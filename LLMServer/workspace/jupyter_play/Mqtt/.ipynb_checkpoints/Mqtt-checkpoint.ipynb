# %%
import json
import paho.mqtt.client as mqtt

# %%
MQTT_BROKER = "localhost"  # MQTTブローカーのホスト名
MQTT_PORT = 1883  # MQTTポート番号（通常は1883）
id = "501cdf38-d399-4270-9e74-9c69c720c60e"
MQTT_TOPIC = "device/" + id  # 送信先のトピック

client = mqtt.Client()
client.connect(MQTT_BROKER, MQTT_PORT)
# Out:
# C:\Users\tenma\AppData\Local\Temp\ipykernel_41484\3384775934.py:6: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
def send(payload):
    """MQTTメッセージを送信"""
    try:
       
        client.publish(MQTT_TOPIC, json.dumps(payload))
        print(f"Message sent to MQTT broker '{MQTT_BROKER}' on topic '{MQTT_TOPIC}':")
        print(json.dumps(payload, indent=4))
    except Exception as e:
        print(f"Error sending MQTT message: {e}")

# %%
payload =  {
            "id": id,
            "state": True,
            "intensity": 100,
            "color": {"r": 255, "g": 255, "b": 255}  # Optional
        }


send(payload)
# Out:
# Message sent to MQTT broker 'localhost' on topic 'device/501cdf38-d399-4270-9e74-9c69c720c60e':
# {
#     "id": "501cdf38-d399-4270-9e74-9c69c720c60e",
#     "state": false,
#     "intensity": 100,
#     "color": {
#         "r": 255,
#         "g": 255,
#         "b": 255
#     }
# }

# %%
# Out:
# '"hello"'
