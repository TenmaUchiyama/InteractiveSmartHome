# %%
import json
import paho.mqtt.client as mqtt

# %%
MQTT_BROKER = "localhost"  # MQTTブローカーのホスト名
MQTT_PORT = 1883  # MQTTポート番号（通常は1883）
id = "09cbfe67-b491-4292-b72d-838a657a6a0a"
MQTT_TOPIC = "device/" + id  # 送信先のトピック

client = mqtt.Client()
client.connect(MQTT_BROKER, MQTT_PORT)
# Out:
# C:\Users\Tenma\AppData\Local\Temp\ipykernel_37096\848368636.py:6: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
def send(payload):
    """MQTTメッセージを送信"""
    try:
       
        client.publish(MQTT_TOPIC, json.dumps(payload))
        client.disconnect()
        print(f"Message sent to MQTT broker '{MQTT_BROKER}' on topic '{MQTT_TOPIC}':")
        print(json.dumps(payload, indent=4))
    except Exception as e:
        print(f"Error sending MQTT message: {e}")

# %%
payload =  {
            "id": id,
            "state": True,
            "intensity": 100,
            "color": {"r": 255, "g": 255, "b": 255}  # Optional
        }


send(payload)
# Out:
# Message sent to MQTT broker 'localhost' on topic 'device/09cbfe67-b491-4292-b72d-838a657a6a0a':
# {
#     "id": "09cbfe67-b491-4292-b72d-838a657a6a0a",
#     "state": true,
#     "intensity": 100,
#     "color": {
#         "r": 255,
#         "g": 255,
#         "b": 255
#     }
# }

# %%
# Out:
# '"hello"'
