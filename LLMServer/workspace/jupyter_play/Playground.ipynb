# %%
import os

os.environ["OPENAI_LOG"] = "debug"

# %%
from langchain_openai import ChatOpenAI 
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from typing import Annotated, List
from typing import Literal
from typing_extensions import TypedDict 
from langchain_core.tools import tool
import os
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %%
os.environ["OPENAI_API_KEY"] = "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"

llm = ChatOpenAI(model="gpt-4o-mini", verbose=True)
messages = [
    SystemMessage(content="あなたは優秀なアシスタントです。"),
    HumanMessage(content="こんにちは！わたしは承太郎です。"),
    AIMessage(content="こんにちは、承太郎さん！あなたのお役にたてるように頑張ります。なにか困ってることはありますか？"),
    HumanMessage(content="わたしの名前は？"),
]



ai_message = llm.invoke(messages)
ai_message
# Out:
# AIMessage(content='あなたの名前は承太郎ですね！ジョジョの奇妙な冒険のキャラクターとしても知られています。何か特別なことについてお話ししたいですか？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 80, 'total_tokens': 123, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47', 'finish_reason': 'stop', 'logprobs': None}, id='run-ccf10812-276e-433e-a12a-fa6cb792a442-0', usage_metadata={'input_tokens': 80, 'output_tokens': 43, 'total_tokens': 123, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
llm.invoke("""
"あいうえおがぎぐげござじずぜぞだぢづでどばびぶべぼぱぴぷぺぽ あぁいぃうぅえぇおぉかゕきくけこさしすせそたちつってとなにぬねのはひふへほまみむめもやゆよらりるれろわをん
ゃゅょアイウエオガギグゲゴザジズゼゾダヂヅデドバビブベボパピプペポサシスセソタチツテトナニヌネノハヒフヘホマミムメモァァィゥゥェォッャュョヮヤユヨワヲン"

足りないひらがな、またはカタカナはありませんか？

もし足りない部分があった場合、補完して下さい。

これはUnityで、TextMeshProでFont Asset Createrに入力するものなので、必要なものを羅列していただくだけで大丈夫です。音やローマ字などはいりません。

例えば、「タチツテト」がない気がします
""")
# Out:
# AIMessage(content='ご指摘の通り、いくつかのひらがなやカタカナが不足しています。以下に足りない部分を補完しました。\n\n### ひらがな\n- たちつてと\n- まみむめも\n- やゆよ\n- らりるれろ\n\n### カタカナ\n- タチツテト\n- マミムメモ\n- ヤユヨ\n- ラリルレロ\n\nこれらを追加することで、ひらがなとカタカナの完全なセットが得られます。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 248, 'total_tokens': 380, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-f9165e86-ca96-4776-ae16-e7a50ddc530e-0', usage_metadata={'input_tokens': 248, 'output_tokens': 132, 'total_tokens': 380, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
@dataclass
class DeviceData:
    device_id: UUID
    distance_from_user: float
    device_position: Tuple[float, float, float]


device = DeviceData(
    device_id=uuid4(),
    distance_from_user = 3.9,
    device_position=(1.0, 2.0, 3.0)  # Vector3に相当
)

def device_list_to_json(device_list: List[DeviceData]) -> str:
    # すべてのDeviceDataオブジェクトを辞書化してUUIDを文字列化
    device_dicts = []
    for device in device_list:
        device_dict = asdict(device)
        device_dict['device_id'] = str(device_dict['device_id'])  # UUIDを文字列化
        device_dicts.append(device_dict)
    return json.dumps(device_dicts, indent=4)  # 配列をJSON文字列に変換
devices = [
    DeviceData(
        device_id=uuid4(),
        distance_from_user = 1.3,
        device_position=(1.0, 2.0, 3.0)
    ),
    DeviceData(
        device_id=uuid4(),
        distance_from_user = 2.1,
        device_position=(4.0, 5.0, 6.0)
    ),
    DeviceData(
        device_id=uuid4(),
        distance_from_user = 3.9,
        device_position=(7.0, 8.0, 9.0)
    )
]

# JSON化
devices_json = device_list_to_json(devices)
print(devices_json)
# Out:
# [
#     {
#         "device_id": "d7bfcaff-45d7-4add-80db-cc3294675a90",
#         "distance_from_user": 1.3,
#         "device_position": [
#             1.0,
#             2.0,
#             3.0
#         ]
#     },
#     {
#         "device_id": "b484fca6-ec44-4bfa-930f-977e35f5dfac",
#         "distance_from_user": 2.1,
#         "device_position": [
#             4.0,
#             5.0,
#             6.0
#         ]
#     },
#     {
#         "device_id": "888b14bb-7f3a-47f6-b833-c0e1a2a5e7f8",
#         "distance_from_user": 3.9,
#         "device_position": [
#             7.0,
#             8.0,
#             9.0
#         ]
#     }
# ]

# %%
from typing import Dict, List, Annotated
import httpx

db_server_url = "http://localhost:4049"



response = httpx.get(db_server_url + "/device/get-all")

if response.status_code == 200:
    response_data = response.json()
    print(f"Response from server: {response_data}")
# Out:
# Response from server: [{'device_id': 'thermo1', 'device_name': 'Thermo Sensor', 'device_type': 'sensor', 'mqtt_topic': 'thermo-sensor', 'device_position': {'x': 0, 'y': 0, 'z': 0}}, {'device_id': 'led-sample-1', 'device_name': 'LED Light', 'device_type': 'actuator', 'mqtt_topic': 'led-actuator', 'device_position': {'x': 0, 'y': 0, 'z': 0}}, {'device_id': 'toggle-device-1', 'device_name': 'Toggle Button Sensor', 'device_type': 'sensor', 'mqtt_topic': 'toggle-button-sensor', 'device_position': {'x': 0, 'y': 0, 'z': 0}}]
